# %%
# Import modules
import pandas as pd
import numpy as np
import pickle
import json

# %%
# Import sklearn modules
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split, ShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import FunctionTransformer
from sklearn.base import TransformerMixin

# %%
from xgboost import XGBClassifier

# %%
# Define categories and category feature columns
categories = ['beauty', 'fashion', 'mobile']
category_feature_columns = {'beauty':[ 'Brand', 'Colour_group', 'Benefits', 'Product_texture', 'Skin_type'], 
                   'fashion': ['Collar Type', 'Sleeves', 'Pattern', 'Fashion Trend', 'Clothing Material'],
                   'mobile': ['Operating System', 'Features',
       'Network Connections', 'Memory RAM', 'Brand', 'Warranty Period',
       'Storage Capacity', 'Color Family', 'Phone Model', 'Camera',
       'Phone Screen Size']}

# %% [markdown]
# # Define all utility functions here

# %%
def train_test_data(df, label, test_size):
    '''Prepare training and test data'''
    df = df[['title', label]]
    df = df.dropna()
    X = df['title']
    y = df[label]
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=test_size)
    return X_train,X_test,y_train,y_test

# %% [markdown]
# # Train SGD model

# %%
def build_SGD_model():
    """
    Build the SGD model
    """ 

    # Build pipeline
    text_clf = Pipeline([('vect', CountVectorizer(token_pattern='\\b\\w+\\b')),
                         ('tfidf', TfidfTransformer()),
                         ('clf', SGDClassifier(loss='modified_huber', max_iter=1000, tol=1e-3, class_weight='balanced'))])


    # Define parameters for grid search
    parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
                'tfidf__use_idf': (True, False),
                'clf__alpha': (1e-1, 1e-5)}


    # Grid search across our parameters, scoring by accuracy
    gs_clf = GridSearchCV(estimator=text_clf, param_grid=parameters, cv=ShuffleSplit(test_size=0.01, n_splits=1), verbose = 10, iid=False, n_jobs=-1, scoring='accuracy')

    return gs_clf

# %%
### Train the SGD model
def train_test_SGD_model(category, column, X_train, y_train):
    SGD_model = build_SGD_model()
    SGD_model.fit(X_train, y_train)
    # Evaluation
    best_params = SGD_model.best_params_
    predicted = SGD_model.predict(X_test)
    print('Best Parameters: ', best_params)
    print('Train Set Accuracy: ', round(SGD_model.best_score_, 2))
    print('Test Set Accuracy: ', round(np.mean(predicted == y_test), 2))
    
    with open ('SGD_clf_21032019_{}_{}.pkl'.format(category, column), 'wb') as f:
        pickle.dump(SGD_model, f)
        
    return SGD_model
#     print('Train set Accuracy (cross val): ', cross_val_score(SGD_model, X_train, y_train, cv=4, scoring='accuracy'))
#     print(classification_report(y_test, predicted))
#     print(confusion_matrix(y_test, predicted))
#     with open ('SGD_clf_28022019_{}.pkl'.format(label), 'wb') as f:
#         pickle.dump(SGD_model, f)

# %%
mobile_feature_columns = ['Operating System']

df_mobile_train = pd.read_csv('../data/mobile_data_info_train_competition.csv')



for column in mobile_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_mobile_train, column, 0.2)
    SGD_model = train_test_SGD_model('mobile', column, X_train, y_train)
# Out:
# Now processing for column: Operating System
# 147230                                     charger iphone 5
# 18850                                         vivo y81 3 16
# 32672                              iphone x show 4g ram 2gb
# 49917     pc lenovo ideacentre 510 core i5 2tb hdd win10...
# 4482      zuk z1 snapdragon ram 3gb rom 64gb 4100mah len...
# 53172                                google pixel 4gb 128gb
# 73582                                              oppo a83
# 60822                               oneplus 3 6gb 64gb grey
# 118163                                         coolpad e502
# 100109                                         redmi 6a tam
# 137001                                     advan tablet i10
# 32194                                           lg l70 sale
# 38322              asus zenfone go zb500kg 1 8 gb 5 inch 3g
# 121357                                          sony z3 3gb
# 56060           terbaik charger iphone usb light 6 s plus 5
# 34900                      goyang shopee iphone 6 16gb gold
# 62643     asus vivobook max x441ua core i3 6006u 500 4gb...
# 145416    hd 5.0 inch 13+8.0mp dual cameras 4g android s...
# 159069                         micromax canvas 6 ram 3 32gb
# 29020                lg l40 dual sim putih bonus jelly skin
# 142139       promo cuci gudang nokia 8 grey wa 083131605470
# 3562      big promo info pembelian via whatsapp:08315233...
# 8737                                  cuci gudang mito a880
# 119428    promo murah new oppo f9 starry purple 6 64 gb ...
# 88040                                 promo vivo v9 ram 6gb
# 65008             iphone 7 128gb original bukan refurbished
# 84359     terpercaya apple lightning multiple strands tp...
# 116351          oppo f7 ram 4gb internal 64gb garansi resmi
# 61945     promoh murah vivo y71 3g lite ram 3 gb rom 32g...
# 84822     preloved samsung galaxy tab a6 with s pen 16gb...
#                                 ...
# 117009    promo cuci gudang spesial minat chat whatsapp ...
# 29668                    new vivo v9 original garansi resmi
# 138253    yuk ready fresh redmi 6a garansi terpercaya ta...
# 12810     diskon 50 nokia 7 plus 64gb ram 4gb brandnew s...
# 159868        baut mur obeng original brandcode b81 b81plus
# 36785     promo big sale xiaomi blackshark ram 8gb inter...
# 13228                 xiaomi mi5s plus ram 6 int 128gb gold
# 77455                   iphone 4s best seller normal lancar
# 67794     samsung galaxy j4 2018 garansi resmi sein 1 tahun
# 110949    beli 1 gratis samsung galaxy s9 garansi resmi ...
# 27130                            promo samsung j7 pro hitam
# 38744                  085244110501 honor 10 ram6gb rom64gb
# 95077                        samsung galaxy tab s 10.5 inch
# 57413                                       nokia 6 android
# 148828                                       iphone 5s 16gb
# 79077                            tablet gramediabook 2 32gb
# 114308    big promo d toko kmi icherry c251 4g lte termu...
# 45688                    oppo a83 2gb garansi resmi 1 tahun
# 96504         vivan robot powerbank rt7200 6600mah original
# 143809                           xiomi redmi 5a garansi tam
# 13260                                               vivo v7
# 124113                               modem wifi andromax m6
# 17000                                vivo y31 garansi resmi
# 148692    terlaris xiaomi mini usb wireless router wifi ...
# 80281                             nokia 4 baru 2017 agustus
# 159072          promo khusus hari ini samsung galaxy c9 pro
# 120730    hp android layar besar chat my via wa 08534250...
# 42771     big sale bulan juli beli 2 geratis 1 produk te...
# 79619      card reader 3in1 untuk smartphone iphone android
# 5262                             fujitsu arrows nx f 05f 4g
# Name: title, Length: 36222, dtype: object
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 418, in _process_worker
#     r = call_item()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 272, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 567, in __call__
#     return self.func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 225, in __call__
#     for func, args, kwargs in self.items]
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 225, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 528, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/pipeline.py", line 265, in fit
#     Xt, fit_params = self._fit(X, y, **fit_params)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/pipeline.py", line 230, in _fit
#     **fit_params_steps[name])
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/memory.py", line 342, in __call__
#     return self.func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/pipeline.py", line 614, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/base.py", line 465, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py", line 133, in fit
#     X = self._check_input(X)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/preprocessing/_function_transformer.py", line 103, in _check_input
#     return check_array(X, accept_sparse=self.accept_sparse)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py", line 527, in check_array
#     array = np.asarray(array, dtype=dtype, order=order)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/numeric.py", line 501, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'wa 083136007555 beli 2 bonus 1 iphone 6 plus 64gb space gray'
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-16324ddab7ee> in <module>
#       9     # Unpack data
#      10     X_train,X_test,y_train,y_test = train_test_data(df_mobile_train, column, 0.2)
# ---> 11     SGD_model = train_test_SGD_model('mobile', column, X_train, y_train)
#
# <ipython-input-12-93ac4888b25c> in train_test_SGD_model(category, column, X_train, y_train)
#       4     SGD_model = build_SGD_model1()
#       5     print (X_train)
# ----> 6     SGD_model.fit(X_train, y_train)
#       7     # Evaluation
#       8     best_params = SGD_model.best_params_
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433             else:
#     434                 raise TimeoutError()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ValueError: could not convert string to float: 'wa 083136007555 beli 2 bonus 1 iphone 6 plus 64gb space gray'

# %%
def build_SGD_model1():
    """
    Build the SGD model
    """ 

    # Build pipeline
    text_clf = Pipeline([('extract_title', FunctionTransformer(get_title)),
                         ('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('clf', SGDClassifier(loss='modified_huber', max_iter=1000, tol=1e-3, class_weight='balanced'))])


    # Define parameters for grid search
    parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
                'tfidf__use_idf': (True, False),
                'clf__alpha': (1e-1, 1e-5)}


    # Grid search across our parameters, scoring by accuracy
    gs_clf = GridSearchCV(estimator=text_clf, param_grid=parameters, cv=5, iid=False, n_jobs=-1, scoring='accuracy')

    return gs_clf

# %%
def get_title(df):
    return df['title']

def get_non_title(df, feature_columns):
    return df[feature_columns]

# %%
text_clf = Pipeline([('extract_title', FunctionTransformer((lambda x: get_non_title(x, feature_columns = ['Operating System'])), validate = False)),
                         ('vect', CountVectorizer())])

X = text_clf.fit_transform(df_mobile_train).toarray()

# %%
df[['title']].values
# Out:
# array([['apple iphone 4s back glass spare part original replacement putih'],
#        ['iphone 4s 64gb white'],
#        ['samsung sm b310e piton dual sim'],
#        ['samsung caramel gt e1272 dual sim 32 mb putih'],
#        ['garskin sony experia z z1 z2 ultra'],
#        ['lcd xiaomi redmi 4+touchscreen'],
#        ['samsung caramel gt e1272 dual sim 32mb black'],
#        ['iphone 4g 8gb'],
#        ['blackberry torch 1 9800 gsm garansi distributor 2 tahun white'],
#        ['samsung keystone 3 sm b109e'],
#        ['samsung galaxy j5 j 500g 8 gb hitam'],
#        ['samsung galaxy j1 mini sm j105 8gb white'],
#        ['iphone 5 white 16gb fullset mulus'],
#        ['lenovo a 6000 se 1 16 white'],
#        ['samsung galaxy j1'],
#        ['keypad blackberry 9360 hitam'],
#        ['xiaomi redmi 3pro 3s'],
#        ['iphone 6s 64gb'],
#        ['iphone 5 garansi 1 thn platinum'],
#        ['iphone 5s 32gb'],
#        ['iphone 4s 16gb black baru garansi 1 tahun'],
#        ['nokia 230 garansi resmi 1 tahun new'],
#        ['samsung galaxy j2 sm j200g 8gb black'],
#        ['hdc samsung galaxy s7 8gb quadcore'],
#        ['original uag urban armor gear trooper series iphone 7 plus 6s 6 black'],
#        ['iphone 5 white 32gb 100 original bersegel'],
#        ['samsung j2 galaxy 4g 8gb'],
#        ['prince pc9000 purple edition'],
#        ['iphone 6s 64gb rosegold second'],
#        ['samsung gt i9082 second paling murah'],
#        ['iphone 5c 16gb 4g biru fullset'],
#        ['iphone 4 8gb white'],
#        ['samsung galaxy j7'],
#        ['infinix zero 4 x555 keluaran pertama tg hardcase smartcover asuransi'],
#        ['xiaomi redmi 4 2 16'],
#        ['iphone 5s 16gb gold second like new'],
#        ['sale samsung galaxy note 5 edge spek gold ori 32gb garansi pin d5cbbdab'],
#        ['xiomi redmi note4 4g lte fullset ram 3gb internal 64gb m'],
#        ['iphone 5s gold 16gb'],
#        ['samsung galaxy s6 flip wallet white'],
#        ['quero p4 3g android'],
#        ['ipad 4 white 16gb 4g celluler wifi'],
#        ['oppo f1s'],
#        ['dijual samsung galaxy j1 mini garansi resmi 1 tahun berkualitas'],
#        ['samsung lipat gt c3520 pink'],
#        ['andromax a 4g lte bonus 65gb terlaris'],
#        ['sony e1'],
#        ['iphone 6 plus 64gb silver'],
#        ['vivo v5'],
#        ['samsung galaxy s6 64gb'],
#        ['asus zenfone 2'],
#        ['blackphone 2 anti sadap nego tipis'],
#        ['bayar di tempat hard plastic cell phone cover for iphone 6 4.7 white'],
#        ['lenovo zuk z2 ram 4gb 64gb new garansi inter 1th'],
#        ['xiaumi redmi note 4 3 64'],
#        ['asus 16x internal s ata bluray disc rewriter bw 16d1ht blu ray optical drive'],
#        ['blackberry z10 4g garansi distributor'],
#        ['samsung galaxy j7'],
#        ['oppo f1'],
#        ['xperia zr docomo ram 2 gb internal 32'],
#        ['samsung galaxy s7 flat 32gb gold'],
#        ['dijual 100 original samsung note s6 s7 edge headset earphone hf murah'],
#        ['samsung tab 3 sm t111'],
#        ['samsung galaxy j7'],
#        ['apple iphone 4 4s lcd new original black'],
#        ['samsung galaxy grand prime plus murah fullset'],
#        ['casing custom case hardcase softcase tipe hp lengkap'],
#        ['samsung galaxy j5'],
#        ['promo armor rugged case cover hardcase kickstand for asus zenfone 2 diskon'],
#        ['lenovo a328 android kitkat quad core 1gb ram garansi resmi 1tahun'],
#        ['vivo v5plus v5 plus 4gb 64gb'],
#        ['baterai lg g3 bl 53yh original murah'],
#        ['armor king aluminium stainless case bumper samsung note 3 silver hari ini saja'],
#        ['sandisk ultra16gb micro sd 48mb s class 10 stok tipis'],
#        ['bluetooth vr cardboard gamepad with remote shutter black menarik'],
#        ['baterai rakkipanda lg g4 bl 51yf double power 6000mah ter hot'],
#        ['samsung galaxy s7 black onyx'],
#        ['5pcs set kabel penghubung fleksibel untuk sinyal antena gps'],
#        ['sony xperia z3 plus atau z4 warna black normal lengkap'],
#        ['diskon baterai samsung galaxy w sgh t589 i8150 oem'],
#        ['xiaomi redmi 4 baby skin ultra thin hard case red 121104'],
#        ['iphone 6 plus 100 original'],
#        ['samsung galaxy c9 pro new bnib garansi international'],
#        ['asus zenfone 5 buzzer bazer bezer speaker lagu aktif'],
#        ['casing nokia 3310 putih combinasi crome'],
#        ['new samsung galaxy on 7'],
#        ['iphone 6s 16gb gold garansi distributor 1 tahun'],
#        ['sony xperia z5 compact 32gb baru original'],
#        ['iphone 5g 32gb black terlock sim card'],
#        ['nokia x2 01 original new refurbish garansi 1 bulan'],
#        ['sony xperia xzs g8232 4 64gb 4g lte white garansi singapore'],
#        ['iphone 6 64gb gold original second'],
#        ['evercoss a54b android 3g'],
#        ['evercoss a74e winner t compo'],
#        ['promo advan vandroid s7a garansi resmi 1 tahun'],
#        ['vivo v5s'],
#        ['xiaomi redmi note2'],
#        ['jual oppo f3 new packing baru garansi 1 tahun'],
#        ['samsung note 5 32gb single sim white ex global fullset mulus 99'],
#        ['iphone 5c 32gb garansi distributor 1 tahun']], dtype=object)

# %%
class DenseTransformer(TransformerMixin):

    def fit(self, X, y=None, **fit_params):
        return self

    def transform(self, X, y=None, **fit_params):
        return X.todense()

# %%
text_clf = Pipeline([('extract_title', FunctionTransformer(get_title, validate = False)),
                         ('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer())])
text_clf2 = Pipeline([('extract_non_title', FunctionTransformer(get_non_title, validate = False))])

union = FeatureUnion(transformer_list = [("pp1", text_clf),("pp2", text_clf2)])
text_clf.fit_transform(df_mobile_train)
# Out:
# <1x1 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Train SGD for beauty

# %%
beauty_feature_columns = [ 'Brand', 'Colour_group', 'Benefits', 'Product_texture', 'Skin_type']

df_beauty_train = pd.read_csv('../data/processed/beauty_train_processed.csv')
df_beauty_train = df_beauty_train[df_beauty_train['language']=='id']

for column in beauty_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_beauty_train, column, 0.2)
    SGD_model = train_test_SGD_model('beauty', column, X_train, y_train)
# Out:
# Now processing for column: Brand
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    8.3s remaining:   24.9s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:   11.1s remaining:   18.5s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:   11.2s remaining:   11.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:   12.3s remaining:    7.4s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:   12.3s remaining:    4.1s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   15.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   15.3s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.98
# Test Set Accuracy:  0.97
# Now processing for column: Colour_group
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.6s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.9s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    0.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    1.0s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    1.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.2s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.92
# Test Set Accuracy:  0.88
# Now processing for column: Benefits
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    1.7s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    1.8s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    1.9s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    2.3s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    2.4s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.6s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.88
# Test Set Accuracy:  0.87
# Now processing for column: Product_texture
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    1.3s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    1.4s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    1.5s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    2.1s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    2.1s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.2s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.96
# Test Set Accuracy:  0.97
# Now processing for column: Skin_type
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.4s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.5s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    0.6s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    0.7s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    0.7s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.7s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.87
# Test Set Accuracy:  0.86

# %%
df_beauty_train = pd.read_csv('../data/processed/beauty_train_processed.csv')
df_beauty_train.shape
# Out:
# (286583, 12)

# %% [markdown]
# ## Train SGD for mobile

# %%
mobile_feature_columns = ['Operating System', 'Features',
       'Network Connections', 'Memory RAM', 'Brand', 'Warranty Period',
       'Storage Capacity', 'Color Family', 'Phone Model', 'Camera',
       'Phone Screen Size']

df_mobile_train = pd.read_csv('../data/processed/mobile_train_processed.csv')

df_mobile_train = df_mobile_train[df_mobile_train['language']=='id']

for column in mobile_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_mobile_train, column, 0.2)
    SGD_model = train_test_SGD_model('mobile', column, X_train, y_train)
# Out:
# Now processing for column: Operating System
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    2.1s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    2.1s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    2.2s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    2.4s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    2.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.5s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.99
# Test Set Accuracy:  0.97
# Now processing for column: Features
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.4s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.6s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    0.6s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    0.7s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    0.7s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.8s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.76
# Test Set Accuracy:  0.74
# Now processing for column: Network Connections
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1906s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.2s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.3s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    0.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.5s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.92
# Test Set Accuracy:  0.9
# Now processing for column: Memory RAM
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.8s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.9s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    1.0s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    1.2s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    1.2s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.3s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.92
# Test Set Accuracy:  0.9
# Now processing for column: Brand
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    4.3s remaining:   12.8s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    5.4s remaining:    9.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    5.4s remaining:    5.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    6.2s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    6.5s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    7.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    7.6s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.99
# Test Set Accuracy:  0.98
# Now processing for column: Warranty Period
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    1.1s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    1.4s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    1.4s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    1.7s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    1.7s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.7s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.93
# Test Set Accuracy:  0.92
# Now processing for column: Storage Capacity
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.8s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.9s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    0.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    1.2s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    1.2s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.3s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.96
# Test Set Accuracy:  0.95
# Now processing for column: Color Family
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    1.4s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    1.8s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    1.8s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    2.2s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    2.2s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.3s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.81
# Test Set Accuracy:  0.82
# Now processing for column: Phone Model
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:   11.6s remaining:   34.9s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:   15.2s remaining:   25.3s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:   15.5s remaining:   15.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:   16.2s remaining:    9.7s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:   17.3s remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   22.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   22.0s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.97
# Test Set Accuracy:  0.97
# Now processing for column: Camera
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.4s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    0.5s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    0.5s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    0.6s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.6s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.8
# Test Set Accuracy:  0.68
# Now processing for column: Phone Screen Size
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.3s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    0.5s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    0.6s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    0.6s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.7s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.75
# Test Set Accuracy:  0.77

# %%
mobile_feature_columns = ['Operating System', 'Features',
       'Network Connections', 'Memory RAM', 'Brand', 'Warranty Period',
       'Storage Capacity', 'Color Family', 'Phone Model', 'Camera',
       'Phone Screen Size']

df_mobile_train = pd.read_csv('../data/mobile_data_info_train_competition.csv')

for column in mobile_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_mobile_train, column, 0.2)
    SGD_model = train_test_SGD_model('mobile', column, X_train, y_train)
# Out:
# Now processing for column: Operating System
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    3.7s remaining:   11.1s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    3.9s remaining:    6.5s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    4.0s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    5.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    5.0s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.1s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.98
# Test Set Accuracy:  0.97
# Now processing for column: Features
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    1.8s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    2.7s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    2.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    3.1s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    3.1s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.5s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.78
# Test Set Accuracy:  0.78
# Now processing for column: Network Connections
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.8s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    1.1s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    1.2s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    1.4s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    1.4s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.5s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.97
# Test Set Accuracy:  0.91
# Now processing for column: Memory RAM
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    2.9s remaining:    8.8s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    3.8s remaining:    6.3s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    4.0s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    4.8s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    4.8s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.1s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.92
# Test Set Accuracy:  0.91
# Now processing for column: Brand
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:   19.5s remaining:   58.6s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:   25.4s remaining:   42.4s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:   25.4s remaining:   25.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:   27.7s remaining:   16.6s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:   27.8s remaining:    9.3s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   33.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   33.3s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.99
# Test Set Accuracy:  0.99
# Now processing for column: Warranty Period
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    3.1s remaining:    9.4s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    5.6s remaining:    9.3s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    5.7s remaining:    5.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    5.8s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    5.8s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    6.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    6.9s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.81
# Test Set Accuracy:  0.8
# Now processing for column: Storage Capacity
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    2.9s remaining:    8.8s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    3.6s remaining:    6.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    3.6s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    4.5s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    4.6s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    4.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    4.9s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.97
# Test Set Accuracy:  0.95
# Now processing for column: Color Family
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    7.5s remaining:   22.5s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    9.5s remaining:   15.8s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    9.9s remaining:    9.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:   11.3s remaining:    6.8s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:   11.4s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   12.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   12.4s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.85
# Test Set Accuracy:  0.83
# Now processing for column: Phone Model
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:  1.5min remaining:  4.5min
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:  2.0min remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:  2.0min remaining:  2.0min
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:  2.1min remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:  2.2min remaining:   43.1s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:  2.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:  2.7min finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.98
# Test Set Accuracy:  0.96
# Now processing for column: Camera
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    1.8s remaining:    5.4s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    2.7s remaining:    4.4s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    2.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    2.8s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    2.8s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.2s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.77
# Test Set Accuracy:  0.7
# Now processing for column: Phone Screen Size
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    1.3s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    2.3s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    2.4s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    2.5s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    2.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.9s finished
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.79
# Test Set Accuracy:  0.78

# %% [markdown]
# ## Train SGD for fashion

# %%
fashion_feature_columns = ['Collar Type', 'Sleeves', 'Pattern', 'Fashion Trend', 'Clothing Material']


df_fashion_train = pd.read_csv('../data/fashion_data_info_train_competition.csv')

for column in fashion_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_fashion_train, column, 0.2)
    SGD_model = train_test_SGD_model('fashion', column, X_train, y_train)
# Out:
# Now processing for column: Collar Type
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.94
# Test Set Accuracy:  0.95
# Now processing for column: Sleeves
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.99
# Test Set Accuracy:  0.99
# Now processing for column: Pattern
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.93
# Test Set Accuracy:  0.94
# Now processing for column: Fashion Trend
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.92
# Test Set Accuracy:  0.92
# Now processing for column: Clothing Material
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 4 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Best Parameters:  {'clf__alpha': 1e-05, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.86
# Test Set Accuracy:  0.86

# %% [markdown]
# # Using SGD model to predict testing dataset

# %%
df_fashion_val = pd.read_csv('../data/fashion_data_info_val_competition.csv')
X_test = df_fashion_val['title']

for column in fashion_feature_columns:
    with open('SGD_clf_02032019_fashion_{}.pkl'.format(column), 'rb') as f:
        SGD_clf = pickle.load(f)
    predicted = SGD_clf.predict(X_test)
    df_fashion_val[column] = predicted

# %%
df_mobile_val = pd.read_csv('../data/mobile_data_info_val_competition.csv')
X_test = df_mobile_val['title']

for column in mobile_feature_columns:
    with open('SGD_clf_02032019_mobile_{}.pkl'.format(column), 'rb') as f:
        SGD_clf = pickle.load(f)
    predicted = SGD_clf.predict(X_test)
    df_mobile_val[column] = predicted

# %%
df_fashion_val.to_csv('fashion_result_0303.csv')

# %%
### Open the json file

with open('../data/beauty_profile_train.json') as f:
    beauty_json = json.load(f)
with open('../data/fashion_profile_train.json') as f:
    fashion_json = json.load(f)
with open('../data/mobile_profile_train.json') as f:
    mobile_json = json.load(f)

# %%
beauty_column_map = {}
for column in beauty_feature_columns:
    beauty_column_map[column] = {v:k for k,v in beauty_json[column].items()}

fashion_column_map = {}
for column in fashion_feature_columns:
    fashion_column_map[column] = {v:k for k,v in fashion_json[column].items()}

mobile_column_map = {}
for column in mobile_feature_columns:
    mobile_column_map[column] = {v:k for k,v in mobile_json[column].items()}

# %%
df_beauty_val_text = df_beauty_val.copy()
for column in beauty_feature_columns:
    df_beauty_val_text.loc[:, column] = df_beauty_val_text[column].map(beauty_column_map[column])
    
df_fashion_val_text = df_fashion_val.copy()
for column in fashion_feature_columns:
    df_fashion_val_text.loc[:, column] = df_fashion_val_text[column].map(fashion_column_map[column])

df_mobile_val_text = df_mobile_val.copy()
for column in mobile_feature_columns:
    df_mobile_val_text.loc[:, column] = df_mobile_val_text[column].map(mobile_column_map[column])

# %%
df_fashion_val_text
# Out:
#            itemid                                              title  \
# 0       670968580  women casual o neck long sleeve lace patchwork...
# 1       475599610  zaful long dress vintage wanita v neck lengan ...
# 2      1652671018  dress skater swing o neck tanpa lengan desain ...
# 3      1705634904  ok dress slim sexy deep v neck lengan panjang ...
# 4      1789421087  noa korean lace embroidery womens crew neck lo...
# 5      1818944472  vintage women christmas lace patchwork o neck ...
# 6      1341150340  ready stock dress v neck tanpa lengan desain p...
# 7      1021592916  women patchwork long sleeve lace o neck beach ...
# 8      1252778162  fashion wanita dress bodycon bandage pensil la...
# 9      1309386587  fashion bohemian women lady dress chiffon chro...
# 10     1770261713  gaun maxi wanita tanpa lengan dengan bahan sif...
# 11     1021248439  women casual 3 4 sleeve lace patchwork hem pul...
# 12     1271590556  dress mini slim sexy o neck tanpa lengan desai...
# 13      622289074  women v neck 3 4 sleeve keyhole empire waist l...
# 14      366284771  fashion wanita dress bodycon bandage pensil la...
# 15      594777742  dress selutut lipit o neck lengan panjang hem ...
# 16     1672863626  sl fashion spring fall women sexy dresses lace...
# 17     1512510362  bayar di tempat sm dress mini wanita sexy tanp...
# 18     1648432571  jumpsuit wanita tanpa lengan dengan kerah v ne...
# 19        9574342  dress maxi v neck lengan pendek batwing gaya v...
# 20     1364222871  women maxi dress floral v neck lace up long sl...
# 21      631205098  women long sleeve v neck lace patchwork pencil...
# 22     1021468341  autumn winter plus size print women dress long...
# 23     1644459678  gaun casual wanita lengan panjang dengan bahan...
# 24     1758467899  women lace floral dress v neck sleeveless bow ...
# 25     1703778606  dress wanita sexy lengan panjang model deep v ...
# 26     1677205423  summer women dress lace floral off shoulder 3 ...
# 27      438665364  dress mini wanita o neck lengan panjang dengan...
# 28     1212178927  dress mini wanita o neck lengan panjang desain...
# 29     1672955068  sl dress mini wanita o neck lengan pendek baha...
# ...           ...                                                ...
# 55410  1800876699  renda baru musim gugur dingin 2018 bawah kemej...
# 55411  1802226985  or matching chiffon dress women s shirt skirt ...
# 55412  1805691177  termurah o neck kaos polos lengan panjang wani...
# 55413  1808514151  termurah nyaman adem halus hangat murah buat l...
# 55414  1810061500  sexy sling 2018 summer slim v neck gold sequin...
# 55415  1810175473  super big sale u2y8 terlaris kemeja jeans leng...
# 55416  1811887624   km strip vina ro kemeja wanita katun rayon putih
# 55417  1812458125        kemeja susan sw wanita rayon bangkok stripe
# 55418  1812744775  bagus nosh chiffon blouse elisabeth korean sty...
# 55419  1813061012                          kaos lengan panjang polos
# 55420  1815625328  ii mens boy raglan 3 4 sleeve baseball plain t...
# 55421  1816743096  dijuall kemeja blus putih wanita kantor polos ...
# 55422  1816812597  bestseller okechuku blouse korea v neck wanita...
# 55423  1817983842  n s fat mm wild hooded cardigan embroidered lo...
# 55424  1818377120  solid color v neck satin front short long bat ...
# 55425  1818626489     women leaf print hollow out chiffon blouse fyl
# 55426  1820012804  murah turtle neck lengan pendek rib t shirt le...
# 55427  1821403935  plus size women casual patchwork single breast...
# 55428  1821585173  kaos wanita t shirt tumblr tee ringer lengan p...
# 55429  1822234059  ready kemeja hem hitam polos lengan panjang wa...
# 55430  1822248989  murah meriah grosir lace lingerie g string sex...
# 55431  1822552014  murah baju kaos pakaian polos o neck cotton co...
# 55432  1823048928     ready basic plain tank top erato wanita grosir
# 55433  1823189662  lagi murah h&m classic floral sleeveless blous...
# 55434  1825019479  cos hotsale high quality women blouse shirts k...
# 55435  1825226347  stock baru atasan blouse wanita kemeja lengan ...
# 55436  1826413179  termurah kemeja wanita atasan baju kerja kanto...
# 55437  1827137407  rl women s summer chiffon shirt trumpet sleeve...
# 55438  1828540009  women casual 3 4 sleeve lace patchwork t shirt...
# 55439  1829477358  wanita s1017 kaos o neck dkny lengan pendek sp...
#
#                                               image_path       Collar Type  \
# 0      fashion_image/b0ca9645c5c3527882d935f17b4c9579...            o neck
# 1      fashion_image/c74af2636e9fe2686981decce3ca5b6c...            v neck
# 2      fashion_image/1f2a2d91f5eb2d80f1dfdcf0b1f50169...            o neck
# 3      fashion_image/fdb6309635ebb5eac5df9c61984ffce5...            v neck
# 4      fashion_image/578e5c74e97128cd25378ef0f0c021cf...            o neck
# 5      fashion_image/dde2d4b3626a6924ea612d32315a5797...            o neck
# 6      fashion_image/d951fbeb548a5a5a2a307b56aa791bfa...            v neck
# 7      fashion_image/4a5fe5c2019b4e466e843dbbe011ef4b...            o neck
# 8      fashion_image/aefb671d09d8ad9004c37103d0f9e4a3...            v neck
# 9      fashion_image/52a94a1c04a1f8b6b30f737521d20fdc...            v neck
# 10     fashion_image/7b3f06e692f61bf2b5bebc8404f3a782...            v neck
# 11     fashion_image/f0bffd2fe5b97e72a766bc5b1adaae98...  off the shoulder
# 12     fashion_image/b398eb50769307af5c04882b6926fdb8...            o neck
# 13     fashion_image/becb272b4a0c4e700a1ac4a4f4e8e094...            o neck
# 14     fashion_image/a13c67f03d447ee535c4ebf8d621c44c...            v neck
# 15     fashion_image/8bcaf1b3af96a4dc09e18e6e8045e41e...            o neck
# 16     fashion_image/f324317d6d2d46d5a204c1ff1b66659d...  off the shoulder
# 17     fashion_image/5495a92ecf3c3908073810be426cd0b7...            o neck
# 18     fashion_image/ae0e32cbd0bf4ddc4f79775a27117876...            v neck
# 19     fashion_image/b86dd6ccc5ce2ce9625160e13e8d1c9a...            v neck
# 20     fashion_image/d5fc5b146219f3b1658d84fdc7ba3e52...            v neck
# 21     fashion_image/4a3494df8b34d8aac3b8e1ab7f1a0502...            o neck
# 22     fashion_image/9d2a2aef7ab84d50e4c6ce4d28923711...            o neck
# 23     fashion_image/3188676c6801c4b6fc12f0209b734dcd...            o neck
# 24     fashion_image/430fc9e8fb570dc5fce29c87f0771612...            v neck
# 25     fashion_image/717c187402a91d03f6e3fb9eb973153f...            v neck
# 26     fashion_image/61eeabec5fe55bd94c55ebbbfd37339b...  off the shoulder
# 27     fashion_image/0fed7fa952b6e3de7f145f9c1fbad28c...            o neck
# 28     fashion_image/1cac521061995be0444997581b97d158...            o neck
# 29     fashion_image/1553425dfe91071d029351c41a912c9c...            o neck
# ...                                                  ...               ...
# 55410  fashion_image/07b0066bea35cfb5873fb61a38d830fc...            v neck
# 55411  fashion_image/f0ce8e4199ec2007b11c2e35ca1edfc5...             lapel
# 55412  fashion_image/d74a52f0f009a3a5fdd9eec7b8e6f4c4...            v neck
# 55413  fashion_image/a669441a176d925b0455bcdea5683f51...            o neck
# 55414  fashion_image/947a8801999305fa2511e60847f5c77a...            v neck
# 55415  fashion_image/4ad1a954e06e7750ae55f33c26333be6...              polo
# 55416  fashion_image/88724ba380f0eccc0c204a8d1dff6ad7...              polo
# 55417  fashion_image/67840e8fe062221ddda9bdbb2e8a193c...              polo
# 55418  fashion_image/cb74c30531c4d6702bc95682694af464...            v neck
# 55419  fashion_image/7c608eda190ad364527f81e47e4a6c0c...              polo
# 55420  fashion_image/f144a61e4828a3b43e7fa31dbcd31b50...            o neck
# 55421  fashion_image/5bdf12fa07770accf9c891fe80a7e7d3...            o neck
# 55422  fashion_image/b7c57c9961c00d90bda668ad833c09b6...            v neck
# 55423  fashion_image/8f3b02d6c3253e85dfaa8b6e2e9e8dc7...            hooded
# 55424  fashion_image/d99fcd6b8bc58a83b075cdc906f992e0...            v neck
# 55425  fashion_image/dd418332454834370011a56f6db11e61...            o neck
# 55426  fashion_image/a23538912257f56f5f4ac67d94fe0a8c...         high neck
# 55427  fashion_image/3fe36a256030fda42497e682bfb4cdae...             lapel
# 55428  fashion_image/c168fbd25878271e7d826a0dbfe3171e...            o neck
# 55429  fashion_image/371faeb61d9167b4494bb1b2875d81d3...            v neck
# 55430  fashion_image/a9cf22b329826a41b87e646c4d178e54...            v neck
# 55431  fashion_image/3ffd393124435df7e2cafe4966e4ea1a...            o neck
# 55432  fashion_image/9c558cc33e1a43636bdbd200f9ec544f...            o neck
# 55433  fashion_image/3976289a613980bce37dbdbe4fc3a753...            v neck
# 55434  fashion_image/32a75ce61bcbc266e5bcdb579fc0ae59...            o neck
# 55435  fashion_image/4bda1e64d3b4738cd2fcf67d52fd7b1f...             lapel
# 55436  fashion_image/85f1b1bc152062b1cc87c4e53b7af66b...            v neck
# 55437  fashion_image/b39777140d57e04aadd0b4b07a86db8b...            v neck
# 55438  fashion_image/3c9f9b654b70b2c80e9f59acdc15a473...            o neck
# 55439  fashion_image/c61ba632459162c5bdc70ea1e6ba3ca1...            o neck
#
#             Sleeves     Pattern  Fashion Trend Clothing Material
# 0       long sleeve   patchwork           sexy              lace
# 1       long sleeve       print  retro vintage           chiffon
# 2        sleeveless   patchwork  retro vintage              lace
# 3       long sleeve       plain           sexy              lace
# 4       long sleeve  embroidery         korean              lace
# 5        sleeveless   patchwork  retro vintage              lace
# 6        sleeveless   patchwork          party              lace
# 7       long sleeve   patchwork          party              lace
# 8        sleeveless       plain           sexy              lace
# 9        sleeveless      stripe       bohemian           chiffon
# 10       sleeveless       plain           sexy           chiffon
# 11       sleeve 3 4   patchwork           sexy              lace
# 12       sleeveless   patchwork           sexy              lace
# 13       sleeve 3 4   patchwork          party              lace
# 14       sleeveless       plain           sexy              lace
# 15      long sleeve   patchwork          party              lace
# 16      long sleeve      floral           sexy              lace
# 17       sleeveless   patchwork           sexy              lace
# 18       sleeveless      floral           sexy              lace
# 19     short sleeve       print  retro vintage         polyester
# 20      long sleeve      floral  retro vintage              lace
# 21      long sleeve   patchwork          party              lace
# 22      long sleeve       print          party             linen
# 23      long sleeve      floral  retro vintage             linen
# 24       sleeveless      floral          party              lace
# 25      long sleeve       plain           sexy            velvet
# 26       sleeve 3 4      floral          party              lace
# 27      long sleeve   patchwork          party              lace
# 28      long sleeve   patchwork          party              lace
# 29     short sleeve       plain          party              lace
# ...             ...         ...            ...               ...
# 55410   long sleeve  wave point         korean              lace
# 55411   long sleeve       check         korean           chiffon
# 55412   long sleeve       plain          basic            cotton
# 55413  short sleeve       print          party            cotton
# 55414    sleeveless   patchwork           sexy         polyester
# 55415   long sleeve       plain         korean             denim
# 55416   long sleeve      stripe          basic             rayon
# 55417   long sleeve      stripe          party             rayon
# 55418    sleeve 3 4  embroidery         korean           chiffon
# 55419   long sleeve       plain          basic            cotton
# 55420    sleeve 3 4       plain          basic            cotton
# 55421   long sleeve       plain         office              lace
# 55422    sleeveless       plain         korean           chiffon
# 55423   long sleeve  embroidery         korean            cotton
# 55424  short sleeve       check         korean             satin
# 55425    sleeveless       print           sexy           chiffon
# 55426  short sleeve       check         office         polyester
# 55427   long sleeve   patchwork           sexy             denim
# 55428  short sleeve       plain          basic            cotton
# 55429   long sleeve       plain          basic             rayon
# 55430    sleeve 3 4     brocade           sexy              lace
# 55431  short sleeve       plain          basic            cotton
# 55432    sleeveless       plain          basic            cotton
# 55433    sleeveless      floral          basic            cotton
# 55434   long sleeve       check         korean            cotton
# 55435   long sleeve       plain          basic            cotton
# 55436   long sleeve  threadwork         office             rayon
# 55437    sleeve 3 4       plain          party           chiffon
# 55438    sleeve 3 4   patchwork           sexy              lace
# 55439  short sleeve  threadwork          basic             rayon
#
# [55440 rows x 8 columns]

# %% [markdown]
# # Training DecisionTree (DT)

# %%
def build_DT_model():
    """
    Build the Decision Tree model
    """ 


    # Build pipeline
    text_clf = Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('clf', DecisionTreeClassifier(random_state=0))])


    # Define parameters for grid search
    parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
                'tfidf__use_idf': (True, False),
                 'clf__max_depth':(1,2,3,4,5),
                 }


    # Grid search across our parameters, scoring by accuracy
    gs_clf = GridSearchCV(estimator=text_clf, param_grid=parameters, cv=5, iid=False, n_jobs=-1, scoring='accuracy')

    return gs_clf

# %%
def train_test_DT_model(category, column, X_train, y_train):
    DT_model = build_DT_model()
    DT_model.fit(X_train, y_train)
    # Evaluation
    best_params = DT_model.best_params_
    predicted = DT_model.predict(X_test)
    
    # Print the score
    best_params = best_params
    print('Best Parameters: ', best_params)
    train_acc = round(DT_model.best_score_, 2)
    print('Train Set Accuracy: ', train_acc)
    test_acc = round(np.mean(predicted == y_test), 2)
    print('Test Set Accuracy: ', test_acc)
    
    DT_train['result'][column] = {}
    DT_train['result'][column]['params'] = best_params
    DT_train['result'][column]['train_acc'] = train_acc
    DT_train['result'][column]['test_acc'] = test_acc
    
    with open ('DT_clf_07032019_DT_{}_{}.pkl'.format(category, column), 'wb') as f:
        pickle.dump(DT_model, f)
        
    return DT_model

# %%
##### Record the json training file for DT

DT_train = {}
DT_train['date'] = '07-03-2019'
DT_train['model'] = 'DecisionTree'
DT_train['model_details'] = {'split': 0.2, 'remarks':'None'}
DT_train['result'] = {}

# %%
fashion_feature_columns = ['Collar Type', 'Sleeves', 'Pattern', 'Fashion Trend', 'Clothing Material']


df_fashion_train = pd.read_csv('../data/fashion_data_info_train_competition.csv')

for column in fashion_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_fashion_train, column, 0.2)
    DT_model = train_test_DT_model('fashion', column, X_train, y_train)
# Out:
# Now processing for column: Collar Type
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.71
# Test Set Accuracy:  0.71
# Now processing for column: Sleeves
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.97
# Test Set Accuracy:  0.97
# Now processing for column: Pattern
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.76
# Test Set Accuracy:  0.76
# Now processing for column: Fashion Trend
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.79
# Test Set Accuracy:  0.79
# Now processing for column: Clothing Material
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.63
# Test Set Accuracy:  0.64

# %%
DT_train
# Out:
# {'date': '07-03-2019',
#  'model': 'DecisionTree',
#  'model_details': {'split': 0.2, 'remarks': 'None'},
#  'result': {'Collar Type': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': True,
#     'vect__ngram_range': (1, 2)},
#    'train_acc': 0.71,
#    'test_acc': 0.71},
#   'Sleeves': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': True,
#     'vect__ngram_range': (1, 1)},
#    'train_acc': 0.97,
#    'test_acc': 0.97},
#   'Pattern': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': True,
#     'vect__ngram_range': (1, 1)},
#    'train_acc': 0.76,
#    'test_acc': 0.76},
#   'Fashion Trend': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': True,
#     'vect__ngram_range': (1, 1)},
#    'train_acc': 0.79,
#    'test_acc': 0.79},
#   'Clothing Material': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': False,
#     'vect__ngram_range': (1, 1)},
#    'train_acc': 0.63,
#    'test_acc': 0.64},
#   'Brand': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': True,
#     'vect__ngram_range': (1, 1)},
#    'train_acc': 0.29,
#    'test_acc': 0.29},
#   'Colour_group': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': True,
#     'vect__ngram_range': (1, 2)},
#    'train_acc': 0.67,
#    'test_acc': 0.68},
#   'Benefits': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': True,
#     'vect__ngram_range': (1, 2)},
#    'train_acc': 0.55,
#    'test_acc': 0.55},
#   'Product_texture': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': False,
#     'vect__ngram_range': (1, 1)},
#    'train_acc': 0.88,
#    'test_acc': 0.88},
#   'Skin_type': {'params': {'clf__max_depth': 5,
#     'tfidf__use_idf': False,
#     'vect__ngram_range': (1, 1)},
#    'train_acc': 0.48,
#    'test_acc': 0.49}}}

# %%
beauty_feature_columns = [ 'Brand', 'Colour_group', 'Benefits', 'Product_texture', 'Skin_type']

df_beauty_train = pd.read_csv('../data/beauty_data_info_train_competition.csv')


for column in beauty_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_beauty_train, column, 0.2)
    DT_model = train_test_DT_model('beauty', column, X_train, y_train)
# Out:
# Now processing for column: Brand
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.29
# Test Set Accuracy:  0.29
# Now processing for column: Colour_group
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.67
# Test Set Accuracy:  0.68
# Now processing for column: Benefits
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 4 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.55
# Test Set Accuracy:  0.55
# Now processing for column: Product_texture
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.88
# Test Set Accuracy:  0.88
# Now processing for column: Skin_type
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.48
# Test Set Accuracy:  0.49

# %%
mobile_feature_columns = ['Operating System', 'Features',
       'Network Connections', 'Memory RAM', 'Brand', 'Warranty Period',
       'Storage Capacity', 'Color Family', 'Phone Model', 'Camera',
       'Phone Screen Size']

df_mobile_train = pd.read_csv('../data/mobile_data_info_train_competition.csv')



for column in mobile_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_mobile_train, column, 0.2)
    SGD_model = train_test_DT_model('mobile', column, X_train, y_train)
# Out:
# Now processing for column: Operating System
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 4 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.94
# Test Set Accuracy:  0.94
# Now processing for column: Features
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.49
# Test Set Accuracy:  0.49
# Now processing for column: Network Connections
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.83
# Test Set Accuracy:  0.82
# Now processing for column: Memory RAM
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.63
# Test Set Accuracy:  0.63
# Now processing for column: Brand
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.74
# Test Set Accuracy:  0.74
# Now processing for column: Warranty Period
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.81
# Test Set Accuracy:  0.81
# Now processing for column: Storage Capacity
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.86
# Test Set Accuracy:  0.86
# Now processing for column: Color Family
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.67
# Test Set Accuracy:  0.68
# Now processing for column: Phone Model
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}
# Train Set Accuracy:  0.21
# Test Set Accuracy:  0.21
# Now processing for column: Camera
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.32
# Test Set Accuracy:  0.32
# Now processing for column: Phone Screen Size
# Best Parameters:  {'clf__max_depth': 5, 'tfidf__use_idf': True, 'vect__ngram_range': (1, 2)}
# Train Set Accuracy:  0.4
# Test Set Accuracy:  0.4

# %%
# Save the result
with open('DT_0703.json', 'w') as outfile:  
    json.dump(DT_train, outfile)

# %%
df_fashion_leak = pd.read_csv('../data/fashion_data_info_val_submission.csv')

# %%
df_fashion_leak.rename(columns={"Clothing Material": "Clothing Material True", "Pattern": "Pattern True",
                              "Sleeves":"Sleeves True", "Collar Type":"Collar Type True", "Fashion Trend": "Fashion Trend True" })
# Out:
#           Id Clothing Material True Pattern True  Sleeves True  \
# 0          0                   lace    patchwork   long sleeve
# 1          1                chiffon        print   long sleeve
# 2          2                   lace    patchwork    sleeveless
# 3          3                   lace        plain   long sleeve
# 4          4                   lace   embroidery   long sleeve
# 5          5                   lace    patchwork    sleeveless
# 6          6                   lace    patchwork    sleeveless
# 7          7                   lace    patchwork   long sleeve
# 8          8                   lace        plain    sleeveless
# 9          9                chiffon       stripe    sleeveless
# 10        10                chiffon        plain    sleeveless
# 11        11                   lace    patchwork    sleeve 3 4
# 12        12                   lace    patchwork    sleeveless
# 13        13                   lace    patchwork    sleeve 3 4
# 14        14                   lace        plain    sleeveless
# 15        15                   lace    patchwork   long sleeve
# 16        16                   lace       floral   long sleeve
# 17        17                   lace    patchwork    sleeveless
# 18        18                   lace       floral    sleeveless
# 19        19                  rayon        print  short sleeve
# 20        20                   lace       floral   long sleeve
# 21        21                   lace    patchwork   long sleeve
# 22        22                  linen        print   long sleeve
# 23        23                  linen       floral   long sleeve
# 24        24                   lace       floral    sleeveless
# 25        25                 velvet        plain   long sleeve
# 26        26                   lace       floral    sleeve 3 4
# 27        27                   lace    patchwork   long sleeve
# 28        28                   lace    patchwork   long sleeve
# 29        29                   lace        plain  short sleeve
# ...      ...                    ...          ...           ...
# 55410  55410                   lace          NaN   long sleeve
# 55411  55411                chiffon          NaN   long sleeve
# 55412  55412                    NaN        plain   long sleeve
# 55413  55413                    NaN        print  short sleeve
# 55414  55414                    NaN        plain           NaN
# 55415  55415                  denim        plain   long sleeve
# 55416  55416                  rayon       stripe           NaN
# 55417  55417                  rayon       stripe           NaN
# 55418  55418                chiffon          NaN           NaN
# 55419  55419                    NaN        plain   long sleeve
# 55420  55420              polyester        plain    sleeve 3 4
# 55421  55421                   lace        plain           NaN
# 55422  55422                chiffon          NaN           NaN
# 55423  55423                 cotton          NaN   long sleeve
# 55424  55424                  satin          NaN           NaN
# 55425  55425                chiffon        print           NaN
# 55426  55426                    NaN          NaN  short sleeve
# 55427  55427                  denim    patchwork   long sleeve
# 55428  55428                 cotton        plain  short sleeve
# 55429  55429                    NaN        plain   long sleeve
# 55430  55430                   lace          NaN           NaN
# 55431  55431                 cotton        plain           NaN
# 55432  55432                 cotton        plain           NaN
# 55433  55433                    NaN       floral    sleeveless
# 55434  55434                    NaN          NaN   long sleeve
# 55435  55435                    NaN        plain   long sleeve
# 55436  55436                    NaN          NaN   long sleeve
# 55437  55437                chiffon        check           NaN
# 55438  55438                   lace    patchwork    sleeve 3 4
# 55439  55439                    NaN          NaN  short sleeve
#
#        Collar Type True Fashion Trend True
# 0                o neck               sexy
# 1                v neck      retro vintage
# 2                o neck      retro vintage
# 3                v neck               sexy
# 4                o neck             korean
# 5                o neck      retro vintage
# 6                v neck              party
# 7                o neck              party
# 8                v neck               sexy
# 9                o neck           bohemian
# 10               v neck               sexy
# 11     off the shoulder               sexy
# 12               o neck               sexy
# 13               v neck              party
# 14               v neck               sexy
# 15               o neck              party
# 16     off the shoulder               sexy
# 17               o neck               sexy
# 18               v neck               sexy
# 19               v neck      retro vintage
# 20               v neck      retro vintage
# 21               v neck              party
# 22               o neck              party
# 23               v neck      retro vintage
# 24               v neck              party
# 25               v neck               sexy
# 26     off the shoulder              party
# 27               o neck              party
# 28               o neck              party
# 29               o neck              party
# ...                 ...                ...
# 55410               NaN             korean
# 55411              polo             korean
# 55412            o neck              basic
# 55413               NaN                NaN
# 55414            v neck               sexy
# 55415               NaN                NaN
# 55416               NaN                NaN
# 55417               NaN                NaN
# 55418               NaN             korean
# 55419               NaN                NaN
# 55420               NaN                NaN
# 55421               NaN                NaN
# 55422            v neck             korean
# 55423            hooded                NaN
# 55424            v neck                NaN
# 55425               NaN                NaN
# 55426         high neck                NaN
# 55427             lapel             office
# 55428               NaN                NaN
# 55429               NaN                NaN
# 55430               NaN               sexy
# 55431            o neck                NaN
# 55432               NaN              basic
# 55433               NaN                NaN
# 55434               NaN             korean
# 55435               NaN                NaN
# 55436               NaN             office
# 55437            v neck                NaN
# 55438               NaN                NaN
# 55439            o neck                NaN
#
# [55440 rows x 6 columns]

# %%
df_fashion_val_text
# Out:
#            itemid                                              title  \
# 0       670968580  women casual o neck long sleeve lace patchwork...
# 1       475599610  zaful long dress vintage wanita v neck lengan ...
# 2      1652671018  dress skater swing o neck tanpa lengan desain ...
# 3      1705634904  ok dress slim sexy deep v neck lengan panjang ...
# 4      1789421087  noa korean lace embroidery womens crew neck lo...
# 5      1818944472  vintage women christmas lace patchwork o neck ...
# 6      1341150340  ready stock dress v neck tanpa lengan desain p...
# 7      1021592916  women patchwork long sleeve lace o neck beach ...
# 8      1252778162  fashion wanita dress bodycon bandage pensil la...
# 9      1309386587  fashion bohemian women lady dress chiffon chro...
# 10     1770261713  gaun maxi wanita tanpa lengan dengan bahan sif...
# 11     1021248439  women casual 3 4 sleeve lace patchwork hem pul...
# 12     1271590556  dress mini slim sexy o neck tanpa lengan desai...
# 13      622289074  women v neck 3 4 sleeve keyhole empire waist l...
# 14      366284771  fashion wanita dress bodycon bandage pensil la...
# 15      594777742  dress selutut lipit o neck lengan panjang hem ...
# 16     1672863626  sl fashion spring fall women sexy dresses lace...
# 17     1512510362  bayar di tempat sm dress mini wanita sexy tanp...
# 18     1648432571  jumpsuit wanita tanpa lengan dengan kerah v ne...
# 19        9574342  dress maxi v neck lengan pendek batwing gaya v...
# 20     1364222871  women maxi dress floral v neck lace up long sl...
# 21      631205098  women long sleeve v neck lace patchwork pencil...
# 22     1021468341  autumn winter plus size print women dress long...
# 23     1644459678  gaun casual wanita lengan panjang dengan bahan...
# 24     1758467899  women lace floral dress v neck sleeveless bow ...
# 25     1703778606  dress wanita sexy lengan panjang model deep v ...
# 26     1677205423  summer women dress lace floral off shoulder 3 ...
# 27      438665364  dress mini wanita o neck lengan panjang dengan...
# 28     1212178927  dress mini wanita o neck lengan panjang desain...
# 29     1672955068  sl dress mini wanita o neck lengan pendek baha...
# ...           ...                                                ...
# 55410  1800876699  renda baru musim gugur dingin 2018 bawah kemej...
# 55411  1802226985  or matching chiffon dress women s shirt skirt ...
# 55412  1805691177  termurah o neck kaos polos lengan panjang wani...
# 55413  1808514151  termurah nyaman adem halus hangat murah buat l...
# 55414  1810061500  sexy sling 2018 summer slim v neck gold sequin...
# 55415  1810175473  super big sale u2y8 terlaris kemeja jeans leng...
# 55416  1811887624   km strip vina ro kemeja wanita katun rayon putih
# 55417  1812458125        kemeja susan sw wanita rayon bangkok stripe
# 55418  1812744775  bagus nosh chiffon blouse elisabeth korean sty...
# 55419  1813061012                          kaos lengan panjang polos
# 55420  1815625328  ii mens boy raglan 3 4 sleeve baseball plain t...
# 55421  1816743096  dijuall kemeja blus putih wanita kantor polos ...
# 55422  1816812597  bestseller okechuku blouse korea v neck wanita...
# 55423  1817983842  n s fat mm wild hooded cardigan embroidered lo...
# 55424  1818377120  solid color v neck satin front short long bat ...
# 55425  1818626489     women leaf print hollow out chiffon blouse fyl
# 55426  1820012804  murah turtle neck lengan pendek rib t shirt le...
# 55427  1821403935  plus size women casual patchwork single breast...
# 55428  1821585173  kaos wanita t shirt tumblr tee ringer lengan p...
# 55429  1822234059  ready kemeja hem hitam polos lengan panjang wa...
# 55430  1822248989  murah meriah grosir lace lingerie g string sex...
# 55431  1822552014  murah baju kaos pakaian polos o neck cotton co...
# 55432  1823048928     ready basic plain tank top erato wanita grosir
# 55433  1823189662  lagi murah h&m classic floral sleeveless blous...
# 55434  1825019479  cos hotsale high quality women blouse shirts k...
# 55435  1825226347  stock baru atasan blouse wanita kemeja lengan ...
# 55436  1826413179  termurah kemeja wanita atasan baju kerja kanto...
# 55437  1827137407  rl women s summer chiffon shirt trumpet sleeve...
# 55438  1828540009  women casual 3 4 sleeve lace patchwork t shirt...
# 55439  1829477358  wanita s1017 kaos o neck dkny lengan pendek sp...
#
#                                               image_path       Collar Type  \
# 0      fashion_image/b0ca9645c5c3527882d935f17b4c9579...            o neck
# 1      fashion_image/c74af2636e9fe2686981decce3ca5b6c...            v neck
# 2      fashion_image/1f2a2d91f5eb2d80f1dfdcf0b1f50169...            o neck
# 3      fashion_image/fdb6309635ebb5eac5df9c61984ffce5...            v neck
# 4      fashion_image/578e5c74e97128cd25378ef0f0c021cf...            o neck
# 5      fashion_image/dde2d4b3626a6924ea612d32315a5797...            o neck
# 6      fashion_image/d951fbeb548a5a5a2a307b56aa791bfa...            v neck
# 7      fashion_image/4a5fe5c2019b4e466e843dbbe011ef4b...            o neck
# 8      fashion_image/aefb671d09d8ad9004c37103d0f9e4a3...            v neck
# 9      fashion_image/52a94a1c04a1f8b6b30f737521d20fdc...            v neck
# 10     fashion_image/7b3f06e692f61bf2b5bebc8404f3a782...            v neck
# 11     fashion_image/f0bffd2fe5b97e72a766bc5b1adaae98...  off the shoulder
# 12     fashion_image/b398eb50769307af5c04882b6926fdb8...            o neck
# 13     fashion_image/becb272b4a0c4e700a1ac4a4f4e8e094...            o neck
# 14     fashion_image/a13c67f03d447ee535c4ebf8d621c44c...            v neck
# 15     fashion_image/8bcaf1b3af96a4dc09e18e6e8045e41e...            o neck
# 16     fashion_image/f324317d6d2d46d5a204c1ff1b66659d...  off the shoulder
# 17     fashion_image/5495a92ecf3c3908073810be426cd0b7...            o neck
# 18     fashion_image/ae0e32cbd0bf4ddc4f79775a27117876...            v neck
# 19     fashion_image/b86dd6ccc5ce2ce9625160e13e8d1c9a...            v neck
# 20     fashion_image/d5fc5b146219f3b1658d84fdc7ba3e52...            v neck
# 21     fashion_image/4a3494df8b34d8aac3b8e1ab7f1a0502...            o neck
# 22     fashion_image/9d2a2aef7ab84d50e4c6ce4d28923711...            o neck
# 23     fashion_image/3188676c6801c4b6fc12f0209b734dcd...            o neck
# 24     fashion_image/430fc9e8fb570dc5fce29c87f0771612...            v neck
# 25     fashion_image/717c187402a91d03f6e3fb9eb973153f...            v neck
# 26     fashion_image/61eeabec5fe55bd94c55ebbbfd37339b...  off the shoulder
# 27     fashion_image/0fed7fa952b6e3de7f145f9c1fbad28c...            o neck
# 28     fashion_image/1cac521061995be0444997581b97d158...            o neck
# 29     fashion_image/1553425dfe91071d029351c41a912c9c...            o neck
# ...                                                  ...               ...
# 55410  fashion_image/07b0066bea35cfb5873fb61a38d830fc...            v neck
# 55411  fashion_image/f0ce8e4199ec2007b11c2e35ca1edfc5...             lapel
# 55412  fashion_image/d74a52f0f009a3a5fdd9eec7b8e6f4c4...            v neck
# 55413  fashion_image/a669441a176d925b0455bcdea5683f51...            o neck
# 55414  fashion_image/947a8801999305fa2511e60847f5c77a...            v neck
# 55415  fashion_image/4ad1a954e06e7750ae55f33c26333be6...              polo
# 55416  fashion_image/88724ba380f0eccc0c204a8d1dff6ad7...              polo
# 55417  fashion_image/67840e8fe062221ddda9bdbb2e8a193c...              polo
# 55418  fashion_image/cb74c30531c4d6702bc95682694af464...            v neck
# 55419  fashion_image/7c608eda190ad364527f81e47e4a6c0c...              polo
# 55420  fashion_image/f144a61e4828a3b43e7fa31dbcd31b50...            o neck
# 55421  fashion_image/5bdf12fa07770accf9c891fe80a7e7d3...            o neck
# 55422  fashion_image/b7c57c9961c00d90bda668ad833c09b6...            v neck
# 55423  fashion_image/8f3b02d6c3253e85dfaa8b6e2e9e8dc7...            hooded
# 55424  fashion_image/d99fcd6b8bc58a83b075cdc906f992e0...            v neck
# 55425  fashion_image/dd418332454834370011a56f6db11e61...            o neck
# 55426  fashion_image/a23538912257f56f5f4ac67d94fe0a8c...         high neck
# 55427  fashion_image/3fe36a256030fda42497e682bfb4cdae...             lapel
# 55428  fashion_image/c168fbd25878271e7d826a0dbfe3171e...            o neck
# 55429  fashion_image/371faeb61d9167b4494bb1b2875d81d3...            v neck
# 55430  fashion_image/a9cf22b329826a41b87e646c4d178e54...            v neck
# 55431  fashion_image/3ffd393124435df7e2cafe4966e4ea1a...            o neck
# 55432  fashion_image/9c558cc33e1a43636bdbd200f9ec544f...            o neck
# 55433  fashion_image/3976289a613980bce37dbdbe4fc3a753...            v neck
# 55434  fashion_image/32a75ce61bcbc266e5bcdb579fc0ae59...            o neck
# 55435  fashion_image/4bda1e64d3b4738cd2fcf67d52fd7b1f...             lapel
# 55436  fashion_image/85f1b1bc152062b1cc87c4e53b7af66b...            v neck
# 55437  fashion_image/b39777140d57e04aadd0b4b07a86db8b...            v neck
# 55438  fashion_image/3c9f9b654b70b2c80e9f59acdc15a473...            o neck
# 55439  fashion_image/c61ba632459162c5bdc70ea1e6ba3ca1...            o neck
#
#             Sleeves     Pattern  Fashion Trend Clothing Material
# 0       long sleeve   patchwork           sexy              lace
# 1       long sleeve       print  retro vintage           chiffon
# 2        sleeveless   patchwork  retro vintage              lace
# 3       long sleeve       plain           sexy              lace
# 4       long sleeve  embroidery         korean              lace
# 5        sleeveless   patchwork  retro vintage              lace
# 6        sleeveless   patchwork          party              lace
# 7       long sleeve   patchwork          party              lace
# 8        sleeveless       plain           sexy              lace
# 9        sleeveless      stripe       bohemian           chiffon
# 10       sleeveless       plain           sexy           chiffon
# 11       sleeve 3 4   patchwork           sexy              lace
# 12       sleeveless   patchwork           sexy              lace
# 13       sleeve 3 4   patchwork          party              lace
# 14       sleeveless       plain           sexy              lace
# 15      long sleeve   patchwork          party              lace
# 16      long sleeve      floral           sexy              lace
# 17       sleeveless   patchwork           sexy              lace
# 18       sleeveless      floral           sexy              lace
# 19     short sleeve       print  retro vintage         polyester
# 20      long sleeve      floral  retro vintage              lace
# 21      long sleeve   patchwork          party              lace
# 22      long sleeve       print          party             linen
# 23      long sleeve      floral  retro vintage             linen
# 24       sleeveless      floral          party              lace
# 25      long sleeve       plain           sexy            velvet
# 26       sleeve 3 4      floral          party              lace
# 27      long sleeve   patchwork          party              lace
# 28      long sleeve   patchwork          party              lace
# 29     short sleeve       plain          party              lace
# ...             ...         ...            ...               ...
# 55410   long sleeve  wave point         korean              lace
# 55411   long sleeve       check         korean           chiffon
# 55412   long sleeve       plain          basic            cotton
# 55413  short sleeve       print          party            cotton
# 55414    sleeveless   patchwork           sexy         polyester
# 55415   long sleeve       plain         korean             denim
# 55416   long sleeve      stripe          basic             rayon
# 55417   long sleeve      stripe          party             rayon
# 55418    sleeve 3 4  embroidery         korean           chiffon
# 55419   long sleeve       plain          basic            cotton
# 55420    sleeve 3 4       plain          basic            cotton
# 55421   long sleeve       plain         office              lace
# 55422    sleeveless       plain         korean           chiffon
# 55423   long sleeve  embroidery         korean            cotton
# 55424  short sleeve       check         korean             satin
# 55425    sleeveless       print           sexy           chiffon
# 55426  short sleeve       check         office         polyester
# 55427   long sleeve   patchwork           sexy             denim
# 55428  short sleeve       plain          basic            cotton
# 55429   long sleeve       plain          basic             rayon
# 55430    sleeve 3 4     brocade           sexy              lace
# 55431  short sleeve       plain          basic            cotton
# 55432    sleeveless       plain          basic            cotton
# 55433    sleeveless      floral          basic            cotton
# 55434   long sleeve       check         korean            cotton
# 55435   long sleeve       plain          basic            cotton
# 55436   long sleeve  threadwork         office             rayon
# 55437    sleeve 3 4       plain          party           chiffon
# 55438    sleeve 3 4   patchwork           sexy              lace
# 55439  short sleeve  threadwork          basic             rayon
#
# [55440 rows x 8 columns]

# %%
fashion = pd.merge(df_fashion_val_text, df_fashion_leak, left_index=True, right_index=True)

# %%
fashion_result = {}

for column in fashion_feature_columns:
    fashion_result[column] = fashion[['{}_x'.format(column), '{}_y'.format(column)]]
    fashion_result[column] = fashion_result[column].loc[fashion_result[column]['{}_x'.format(column)]!=fashion_result[column]['{}_y'.format(column)]]

# %%
fashion_result['Clothing Material']
# Out:
#       Clothing Material_x Clothing Material_y
# 19              polyester               rayon
# 485                cotton                 NaN
# 486                 rayon                 NaN
# 489                cotton                 NaN
# 490                cotton                 NaN
# 491                 nylon           polyester
# 492                cotton                 NaN
# 493             polyester              cotton
# 495             polyester                 NaN
# 499                cotton                 NaN
# 500                 rayon                 NaN
# 501                cotton                 NaN
# 504                 rayon           polyester
# 505                cotton                 NaN
# 506             polyester                 NaN
# 507                 rayon                 NaN
# 511             polyester                 NaN
# 512                  silk                 NaN
# 515                 rayon                 NaN
# 517                cotton                 NaN
# 520                cotton                 NaN
# 521                cotton                 NaN
# 522                 nylon                 NaN
# 524                cotton                 NaN
# 525                cotton                 NaN
# 530                cotton                 NaN
# 531                cotton                 NaN
# 534             polyester                 NaN
# 537                cotton                 NaN
# 539                 rayon              cotton
# ...                   ...                 ...
# 55373           polyester                 NaN
# 55374              cotton                 NaN
# 55377              cotton                 NaN
# 55378           polyester              cotton
# 55380           polyester                 NaN
# 55381              cotton                 NaN
# 55382              cotton                 NaN
# 55384               rayon                 NaN
# 55385                wool                 NaN
# 55386              cotton                 NaN
# 55389           polyester                 NaN
# 55390           polyester                 NaN
# 55395              cotton                 NaN
# 55396              cotton                 NaN
# 55397              cotton                 NaN
# 55399              cotton                 NaN
# 55406              cotton                 NaN
# 55408               satin           polyester
# 55412              cotton                 NaN
# 55413              cotton                 NaN
# 55414           polyester                 NaN
# 55419              cotton                 NaN
# 55420              cotton           polyester
# 55426           polyester                 NaN
# 55429               rayon                 NaN
# 55433              cotton                 NaN
# 55434              cotton                 NaN
# 55435              cotton                 NaN
# 55436               rayon                 NaN
# 55439               rayon                 NaN
#
# [24936 rows x 2 columns]

# %%
df_fashion_leak['Fashion Trend'].isna().sum()
# Out:
# 32287

# %%
#### Evaluation

# Evaluation
best_params = SGD_model.best_params_
predicted = SGD_model.predict(X_test)
print('Best Parameters: ', best_params)
print('Train Set Accuracy: ', round(SGD_model.best_score_, 2))
print('Test Set Accuracy: ', round(np.mean(predicted == y_test), 2))
print('Train set Accuracy (cross val): ', cross_val_score(SGD_model, X_train, y_train, cv=5, scoring='accuracy'))
print(classification_report(y_test, predicted))
print(confusion_matrix(y_test, predicted))

# %%
df_mobile_val_text
# Out:
#            itemid                                              title  \
# 0      1520485457        new promo iphone 5s 16gb gold ex resmi ibox
# 1      1520516704          new promo xiaomi note 5a prime 3 32gb tam
# 2      1520726573    big produk super murah oppo f5 4gb 32gb fullset
# 3      1523303826              pocophone xiaomi f1 ram 6gb rom 128gb
# 4      1524467616                                           advan g2
# 5      1524876429                                  samsung galaxy a6
# 6      1525744340  promo akhir bulan oppo f7 diamond black limite...
# 7      1529179598                     vivo v9 pro ram 6gb rom 64gb 6
# 8      1529634640  unik telephone panasonic wireless kx tg1611 bl...
# 9      1529634708  promo telepon wireless panasonic kx tg1611 all...
# 10     1535594128  big promo terbaru baru diskon 55 samsung galax...
# 11     1536913818                               aldo al007 ht antena
# 12     1537000139                   nokia 216 dual sim garansi resmi
# 13     1539694249    promo samsung original galaxy s4 earphone white
# 14     1539930818  promo hari jadi toko kami stock terbatas asus ...
# 15     1539935384  promo hari jadi toko kami stock terbatas iphon...
# 16     1541268292                   lcd asus t00n original padfone s
# 17     1541736960  terlaris asli meizu m2 note 4g fdd lte dual si...
# 18     1541759005                                      promo nokia 3
# 19     1543195129                                advan s5e full view
# 20     1544282937                       moshi iphone 6 6s sensecover
# 21     1546128724  big sale laris iphone 6 16gb gold garansi dist...
# 22     1548186789                                iphone 6s 64gb gold
# 23     1549681613  bestproduct stainless connector adapter for sa...
# 24     1551600002  usb cable lighting kabel data iphone 5 6 origi...
# 25     1551898546                usb port penutup sony xperia z1 ori
# 26     1555335464                                 xiomi redmi 5 3 32
# 27     1557002061  anker powerline lightning mfi certified cable ...
# 28     1557042701  handsfree headset earpods iphone 8 plus x orig...
# 29     1557837884          promo xiaomi mi a2 androidone ready stock
# ...           ...                                                ...
# 40387  1216935158                                 oppo r11s new bnib
# 40388   311199291                oppo a39 gold ram 3gb internal 32gb
# 40389  1694824763  nokia 6 4g lte ram 3gb rom 32gb segel murah ga...
# 40390  1034284267  ready stock sharp r1 5.2 ips hd 3 32gb 13 8 mp...
# 40391  1059390085                    promo infinix hot s3 topaz blue
# 40392  1839788366                  iphone 7 gold 32gb garansi 1tahun
# 40393   704126195  evercoss genpro z 4g lte ram 4gb 32gb garansi ...
# 40394  1210020180  diskon15 infinix hot s3 3 32gb layar 18:9 self...
# 40395  1568003530  diskon 50 cuci gudang asus zenfone 5q 4 64 zc6...
# 40396  1186786053           sharp m1 aquos 4g lte ram 3gb 64gb resmi
# 40397  1822896387  asus zenfone max m2 3gb 32gb zb633kl midnight ...
# 40398   919038573  minat serius chat di wa 083123426159 iphone 5s...
# 40399  1839836526  big promo add whatshap 0821 9127 5399 iphone 7...
# 40400  1397082442  ready samsung galaxy j8 2018 edition gold gara...
# 40401  1740028202  promo xiaomi mi a2 prime ram 6gb internal 128g...
# 40402   349452481  asus zenfone zoom s ze553kl free tongsis rings...
# 40403  1098672042  unik xiaomi mi a1 4g lte ram 4gb 64gb black ga...
# 40404  1761239629  big promo akhir tahun distributor asus zenfone...
# 40405  1839767194                   iphone 7 red 32gb garansi 1tahun
# 40406   976294675                     vivo y69 ram 3gb rom 32gb 4lte
# 40407  1388680945  super sale agustus samsung galaxy a8 star 2018...
# 40408   966489015                  oppo f5 4 32 gold garansi 1 tahun
# 40409  1013677956  bli 2 gratis 1 wa 082292409969 vivo v7 gold ra...
# 40410  1038729298  promo cuci gudang spesial gudan beli 2 gratis ...
# 40411  1062060975  promo khusus hari ini saja infinix hot s3 x573...
# 40412  1781957365  nokia 5.1 plus ram 3gb 32gb garansi resmi 1 ta...
# 40413  1839851276  big promo add whatshap 0821 9127 5399 iphone 7...
# 40414   955369303  datang lagi sharp r1 ram 3gb 32gb gratis silic...
# 40415  1638035772  sony xperia z5 premium au ram 3gb rom 32gb sec...
# 40416  1498091427                      xiaomi mi 8 ram 6 128gb black
#
#                                               image_path Operating System  \
# 0      mobile_image/876d4a1fe29e056855fa6f9643757b1c.jpg              ios
# 1      mobile_image/e2b902b7cd35cd50f061d8e2a3ba7178.jpg          android
# 2      mobile_image/785c03cb1a21a1efedb8c1bbbdb81035.jpg          android
# 3      mobile_image/08bb7a43ae0fafd568ad54db908bac0b.jpg          android
# 4      mobile_image/970134be2e5961bda177e9761e1cf6ab.jpg          android
# 5      mobile_image/ce06b7eb04ff32e0ba9bd8de93b47955.jpg          android
# 6      mobile_image/9c4ed6c4eb9fe1bbfdb873f527896506.jpg          android
# 7      mobile_image/8af91359e6b7f04d8099748d8fbdd200.jpg          android
# 8      mobile_image/f50c21529d6d99a7aa9bafdb56fbe3a8.jpg          android
# 9      mobile_image/a3f4f39dad3ec46faf58d9f0e8d4d0f5.jpg          android
# 10     mobile_image/dd8eefd7bfae12acc5439f0801368e34.jpg          android
# 11     mobile_image/8fec8ca723794215d379546634a6b467.jpg          android
# 12     mobile_image/9942d12dbe0841d5c96033347f71cdad.jpg          android
# 13     mobile_image/5b11bb20ea310b7e89b85cb2e18266a8.jpg          android
# 14     mobile_image/e09df02213c07784b916a9d086485e3c.jpg          android
# 15     mobile_image/08fd287bc478ae6c9299cbbfc63912c2.jpg              ios
# 16     mobile_image/8b78984bc05d1babfb714d46325f415d.jpg          android
# 17     mobile_image/df0a3e08b194f738d39d14b1f9e0887e.jpg          android
# 18     mobile_image/e3628a6f277f151f64078f31c2516c1d.jpg          android
# 19     mobile_image/c75e88f85759bf194ad0953e307759db.jpg          android
# 20     mobile_image/cd0bb8c56a1ceca989a33bdefb533868.jpg              ios
# 21     mobile_image/f8a5789e78ddb0fb068b76dc5b142327.jpg              ios
# 22     mobile_image/62bdac796e40d62e23c3e0aa93ce9c88.jpg              ios
# 23     mobile_image/e5fedd171ada4619a7d883761c9156f1.jpg          android
# 24     mobile_image/945b74c745988d3288bd56380d896dd9.jpg              ios
# 25     mobile_image/2142abcee07401ab79b232ce6acd072b.jpg          android
# 26     mobile_image/5f10983bca82b5c28e4153b2c1ec5b79.jpg          android
# 27     mobile_image/57815a9e819709f0ecbd4d8b481ce968.jpg          android
# 28     mobile_image/c52428f4967cc2e73baf000a493b39cb.jpg              ios
# 29     mobile_image/1115e587d8e53d56157b9ca2fc89024b.jpg          android
# ...                                                  ...              ...
# 40387  mobile_image/f0751f01d81d6527018c161cfc29ca4a.jpg          android
# 40388  mobile_image/092f35beea97b2b5f989d5f658fdc0f9.jpg          android
# 40389  mobile_image/7dd9172e8f8da1274ecafabecef309ea.jpg          android
# 40390  mobile_image/d3c6c4ba3d51496828ec4d12087ac70c.jpg          android
# 40391  mobile_image/c95b1d431b4bb522fa7d6b8af0e8b599.jpg          android
# 40392  mobile_image/aa5faeff09fe4e1f74332a0a71112126.jpg              ios
# 40393  mobile_image/652a463961e37ee1cbde207367384a2f.jpg          android
# 40394  mobile_image/1a9dd9bf474fb79f4a0980226d482454.jpg          android
# 40395  mobile_image/cb2797dd2bd6be9178599d787609480e.jpg          android
# 40396  mobile_image/83adb7a0aeb8f3fc6457164fb28444ed.jpg          android
# 40397  mobile_image/896dc978860e38b092fba3c7dc97e830.jpg          android
# 40398  mobile_image/542f2eb6810bd8d3b62d92e1dab33bc7.jpg              ios
# 40399  mobile_image/7df4833f2683c89f9009688dad4541c0.jpg              ios
# 40400  mobile_image/1d8f791041590e7de4286702f57f7bb2.jpg          android
# 40401  mobile_image/17ae0a8ae4da4363b31685f509beff2f.jpg          android
# 40402  mobile_image/177787347e3b058707b644825149d8c6.jpg          android
# 40403  mobile_image/dac07096a5a8905b1b01cff9dd617d13.jpg          android
# 40404  mobile_image/db3e640d9168a0090723bba49e27cf3a.jpg          android
# 40405  mobile_image/2614f45db17795b21e668ef494f596e8.jpg              ios
# 40406  mobile_image/209a103c811bb208cd4a01c05ffb3434.jpg          android
# 40407  mobile_image/83f130a0f3acb1e2e24cad9e3a89cc44.jpg          android
# 40408  mobile_image/acd4525c0b6fbf654285d77bbe341d17.jpg          android
# 40409  mobile_image/431aaec705e039327834960f37f6654b.jpg          android
# 40410  mobile_image/a5d932dbcfa90f2eb8684fc187b6593c.jpg          android
# 40411  mobile_image/456f628f268a1f793ae03624b585a17c.jpg          android
# 40412  mobile_image/3dbd99b9d999d326d8ae57f7ad1f1b3e.jpg          android
# 40413  mobile_image/6d45e5c7e36ac897f58a9f72ff4bf0b8.jpg              ios
# 40414  mobile_image/08f68bb1cc3f381364776ac5cfd9e45e.jpg          android
# 40415  mobile_image/1d0610ea0f43d75ecc3ff951f6c647d4.jpg          android
# 40416  mobile_image/6649fa043a7b2eebda6ed904c966a14b.jpg          android
#
#                  Features Network Connections Memory RAM     Brand  \
# 0      fingerprint sensor                  4g       16gb     apple
# 1             touchscreen                  2g        3gb    xiaomi
# 2      fingerprint sensor                  4g        4gb      oppo
# 3             touchscreen                  4g        6gb    xiaomi
# 4      fingerprint sensor                  4g        3gb     advan
# 5             touchscreen                  4g        3gb   samsung
# 6                     gps                  4g        4gb      oppo
# 7              waterproof                  4g        6gb      vivo
# 8      fingerprint sensor                  3g        4gb        hp
# 9      fingerprint sensor                  3g        4gb        hp
# 10            touchscreen                  4g        4gb   samsung
# 11                   wifi                  2g       16gb      aldo
# 12                    gps                  2g        8gb     nokia
# 13            touchscreen                  4g        2gb   samsung
# 14            touchscreen                  4g        6gb      asus
# 15            touchscreen                  4g        1gb     apple
# 16            touchscreen                  4g       16gb      asus
# 17                    gps                  4g        2gb        hp
# 18            touchscreen                  4g       16gb     nokia
# 19                    gps                  4g        1gb     advan
# 20            touchscreen                  4g      512mb     apple
# 21            touchscreen                  4g       16gb     apple
# 22     fingerprint sensor                  4g        2gb     apple
# 23                    gps                  3g        3gb   samsung
# 24            touchscreen                  4g        2gb     apple
# 25            touchscreen                  4g        2gb      sony
# 26     fingerprint sensor                  4g        3gb    xiaomi
# 27            touchscreen                  4g        2gb     apple
# 28            touchscreen                  4g        2gb     apple
# 29            touchscreen                  4g        4gb    xiaomi
# ...                   ...                 ...        ...       ...
# 40387  fingerprint sensor                  4g        4gb      oppo
# 40388         touchscreen                  4g        3gb      oppo
# 40389         touchscreen                  4g        3gb     nokia
# 40390  fingerprint sensor                  4g        4gb     sharp
# 40391  fingerprint sensor                  4g        3gb   infinix
# 40392         touchscreen                  4g        2gb     apple
# 40393  fingerprint sensor                  4g        4gb  evercoss
# 40394  fingerprint sensor                  4g        3gb   infinix
# 40395  fingerprint sensor                  3g        4gb      asus
# 40396         touchscreen                  4g        3gb     sharp
# 40397  fingerprint sensor                  4g        3gb      asus
# 40398         touchscreen                  4g        4gb     apple
# 40399         touchscreen                  4g        2gb     apple
# 40400         touchscreen                  4g        3gb   samsung
# 40401         touchscreen                  4g        6gb    xiaomi
# 40402         touchscreen                  4g        4gb      asus
# 40403  fingerprint sensor                  4g        4gb    xiaomi
# 40404  fingerprint sensor                  4g        4gb      asus
# 40405         touchscreen                  4g        2gb     apple
# 40406  fingerprint sensor                  4g        3gb      vivo
# 40407         touchscreen                  4g        4gb   samsung
# 40408         touchscreen                  4g        4gb      oppo
# 40409  fingerprint sensor                  4g        4gb      vivo
# 40410         touchscreen                  4g        3gb      vivo
# 40411  fingerprint sensor                  4g        3gb   infinix
# 40412  fingerprint sensor                  4g        3gb     nokia
# 40413         touchscreen                  4g        2gb     apple
# 40414  fingerprint sensor                  4g        3gb     sharp
# 40415          waterproof                  4g        3gb      sony
# 40416         touchscreen                  4g        6gb    xiaomi
#
#       Warranty Period Storage Capacity Color Family             Phone Model  \
# 0            3 months             32gb         gold         apple iphone 5s
# 1              1 year             32gb         gold    xiaomi note 5a prime
# 2              1 year             32gb         gold                 oppo f5
# 3              1 year            128gb        black     xiaomi pocophone f1
# 4             1 month             32gb        white                 oppo f9
# 5           18 months             32gb        black       samsung galaxy a6
# 6             2 month             64gb        black                 oppo f7
# 7             1 month             64gb          red                 vivo v9
# 8              1 year             64gb        black          apple iphone 7
# 9              1 year             32gb        white   samsung galaxy note 8
# 10             1 year             32gb        black       samsung galaxy a6
# 11             1 year            256mb        black          asus zenfone 5
# 12             1 year             32gb         blue               nokia 216
# 13            2 years             32gb        white       samsung galaxy s5
# 14             1 year             32gb        black    asus zenfone max pro
# 15            1 month             64gb         gold          apple iphone x
# 16            1 month             64gb        black          asus padfone s
# 17             1 year             64gb        black   samsung galaxy note 5
# 18            2 years              4mb        black                 nokia 5
# 19             1 year             32gb        white                 vivo v9
# 20             1 year            128gb        black         apple iphone 6s
# 21             1 year             32gb         gold          apple iphone 6
# 22             1 year             64gb         gold         apple iphone 6s
# 23            1 month            256gb       silver         samsung gear s2
# 24            1 month             64gb        white          apple iphone 4
# 25             1 year             32gb        white          sony xperia z1
# 26             1 year             32gb         gold            xiaomi redmi
# 27          18 months             32gb        white          apple iphone 5
# 28            1 month             64gb        white          apple iphone 7
# 29             1 year             64gb        black            xiaomi mi a2
# ...               ...              ...          ...                     ...
# 40387         1 month             64gb          red               oppo r11s
# 40388          1 year             32gb         gold                oppo a39
# 40389          1 year             32gb        black                 nokia 2
# 40390          1 year             32gb         gold                sharp r1
# 40391         1 month             32gb         blue          infinix hot s3
# 40392          1 year             32gb         gold          apple iphone 6
# 40393         1 month             32gb        black          asus zenfone 2
# 40394          1 year             32gb         blue          infinix hot s3
# 40395          1 year             64gb        black         asus zenfone 5q
# 40396          1 year             64gb         pink                sharp m1
# 40397          1 year             32gb        black     asus zenfone max m2
# 40398          1 year             64gb       silver         apple iphone 5s
# 40399          1 year            128gb          red          apple iphone 7
# 40400          1 year             32gb         gold       samsung galaxy j8
# 40401          1 year            128gb         gold            xiaomi mi a2
# 40402          1 year             64gb        black       asus zenfone zoom
# 40403          1 year             64gb        black            xiaomi mi a1
# 40404          1 year             64gb        white         asus zenfone 5q
# 40405          1 year             32gb          red          apple iphone 7
# 40406          1 year             32gb         gold                vivo y69
# 40407          1 year             64gb        white  samsung galaxy a8 star
# 40408          1 year             32gb         gold                 oppo f5
# 40409          1 year             32gb         gold                 vivo v7
# 40410          1 year             32gb        black                 vivo v7
# 40411          1 year             32gb         blue          infinix hot s3
# 40412          1 year             32gb        black                 nokia 6
# 40413          1 year             32gb         gold          apple iphone 7
# 40414          1 year             32gb         gold                sharp r1
# 40415         1 month             32gb       silver          sony xperia z5
# 40416        5 months            128gb        black             xiaomi mi 6
#
#               Camera     Phone Screen Size
# 0           dua slot       3.6 to 4 inches
# 1               16mp     5.1 to 5.5 inches
# 2               16mp  less than 3.5 inches
# 3           dua slot       4.6 to 5 inches
# 4               13mp  more than 5.6 inches
# 5               16mp  more than 5.6 inches
# 6               16mp       4.6 to 5 inches
# 7               13mp  more than 5.6 inches
# 8      single camera     4.1 to 4.5 inches
# 9      single camera     4.1 to 4.5 inches
# 10     single camera  more than 5.6 inches
# 11          dua slot       4.6 to 5 inches
# 12     single camera       3.6 to 4 inches
# 13              13mp  less than 3.5 inches
# 14              16mp  more than 5.6 inches
# 15          dua slot       4.6 to 5 inches
# 16          dua slot       4.6 to 5 inches
# 17              13mp  more than 5.6 inches
# 18     single camera     5.1 to 5.5 inches
# 19          dua slot       4.6 to 5 inches
# 20     single camera       4.6 to 5 inches
# 21              8 mp       4.6 to 5 inches
# 22              5 mp       4.6 to 5 inches
# 23     single camera     4.1 to 4.5 inches
# 24          dua slot  less than 3.5 inches
# 25     single camera     4.1 to 4.5 inches
# 26              5 mp  more than 5.6 inches
# 27          dua slot  less than 3.5 inches
# 28          dua slot  less than 3.5 inches
# 29          dua slot  less than 3.5 inches
# ...              ...                   ...
# 40387           13mp  more than 5.6 inches
# 40388           13mp     5.1 to 5.5 inches
# 40389           13mp       4.6 to 5 inches
# 40390           13mp     5.1 to 5.5 inches
# 40391          20 mp  more than 5.6 inches
# 40392           8 mp       4.6 to 5 inches
# 40393           13mp     5.1 to 5.5 inches
# 40394           13mp  more than 5.6 inches
# 40395           16mp     4.1 to 4.5 inches
# 40396           13mp  more than 5.6 inches
# 40397           8 mp  more than 5.6 inches
# 40398           8 mp       3.6 to 4 inches
# 40399  single camera       4.6 to 5 inches
# 40400           16mp  more than 5.6 inches
# 40401  single camera  more than 5.6 inches
# 40402           13mp     5.1 to 5.5 inches
# 40403       dua slot     5.1 to 5.5 inches
# 40404           16mp     4.1 to 4.5 inches
# 40405  single camera       4.6 to 5 inches
# 40406           16mp  more than 5.6 inches
# 40407          24 mp  more than 5.6 inches
# 40408           16mp  more than 5.6 inches
# 40409           16mp  more than 5.6 inches
# 40410           8 mp     5.1 to 5.5 inches
# 40411          20 mp  more than 5.6 inches
# 40412  single camera     5.1 to 5.5 inches
# 40413  single camera       4.6 to 5 inches
# 40414           13mp  more than 5.6 inches
# 40415  single camera  more than 5.6 inches
# 40416           16mp  less than 3.5 inches
#
# [40417 rows x 14 columns]

# %%
beauty_json['Brand']
# Out:
# {'selection': 0,
#  'bio hair': 124,
#  'katy perry': 2,
#  'cw 666': 3,
#  'random': 4,
#  'wet n wild': 5,
#  'chanel': 212,
#  'pomparians': 6,
#  'xl professionnel': 36,
#  'herborist': 9,
#  'cantiqa kemiri': 10,
#  'catok haidi': 11,
#  'dettol': 12,
#  'hadalabo': 13,
#  'pepsodent': 14,
#  'pratista': 103,
#  'dolce gabbana': 368,
#  'evangeline': 16,
#  'cocco': 17,
#  'scarlett': 18,
#  'colourpop': 19,
#  'little baby': 20,
#  'avoskin': 21,
#  'moodmatcher': 22,
#  'sasha': 23,
#  'davidoff': 24,
#  'makarizo viola': 25,
#  'miniso': 108,
#  'kemei': 28,
#  'bebold': 140,
#  'erto s': 30,
#  'rudy hadisuwarno': 31,
#  'kirkland signature': 32,
#  'haidi': 33,
#  'marc jacobs': 34,
#  'jo malone': 35,
#  'ellips': 7,
#  'l oreal paris': 104,
#  'real techniques': 38,
#  'musk by lilian ashley': 39,
#  'sonar': 40,
#  'olay': 41,
#  'ql': 42,
#  'zwitsbaby': 271,
#  'natur': 45,
#  'satto': 46,
#  'revlon': 47,
#  'emina': 48,
#  'envygreen': 49,
#  'peripera': 50,
#  'natrol': 51,
#  'champagne': 63,
#  'glamglow': 52,
#  'elise': 53,
#  'paris hilton': 376,
#  'la rive': 54,
#  'christian jornald': 55,
#  'catrice': 56,
#  'kemier': 57,
#  'tammia': 58,
#  'moreskin': 59,
#  'gucci': 60,
#  'dundee': 61,
#  'innisfree': 205,
#  'lt pro': 260,
#  'paco rabanne': 275,
#  'mane&tail': 65,
#  'pyunkang yul': 66,
#  'ms glow': 67,
#  'lakme': 68,
#  'choirose': 69,
#  'ichikawa': 70,
#  '3ce': 71,
#  'mizzu': 72,
#  'etude house': 73,
#  'al rehab': 74,
#  'good virtues co': 168,
#  'johnny andrean': 75,
#  'glutax': 231,
#  'amori': 76,
#  'gemmini': 112,
#  'miyako': 235,
#  'masami shouko': 121,
#  'peo mix': 81,
#  'mitsuyama': 137,
#  'garnier': 83,
#  'flormar': 208,
#  'barbara walden': 85,
#  'la roche posay': 86,
#  'the body shop': 87,
#  'meisa': 88,
#  'pixy': 173,
#  'adidas': 90,
#  'missha': 91,
#  'ruida': 92,
#  'star pomade': 93,
#  'bourjois': 94,
#  'marlboro pomade': 228,
#  'elsheskin': 96,
#  'krasava': 97,
#  'leivy': 357,
#  'by lizzie parra': 98,
#  'x pert': 99,
#  'the saem': 101,
#  'pioneer pomade': 102,
#  'makarizo': 15,
#  'nutrilash': 8,
#  'gillette': 105,
#  'maybelline': 282,
#  'shantos romeo': 107,
#  'mezbareta': 314,
#  'bulgari': 110,
#  'msi': 329,
#  'wardah': 77,
#  'bioderma': 113,
#  'veet': 78,
#  'chateau labiotte': 115,
#  'the face shop': 284,
#  'pinklab.co': 117,
#  'neha': 118,
#  'oh man': 119,
#  'onyx': 120,
#  'elsheskin x tasya farasya': 79,
#  'beauty treats': 122,
#  'blumarine': 123,
#  'dior': 1,
#  'ultima ii': 125,
#  'sebamed': 126,
#  'the balm': 127,
#  'namir beauty': 361,
#  'klairs': 129,
#  'puritan s pride': 130,
#  'napoleon': 131,
#  'zaza': 132,
#  'acnes': 133,
#  'avajar': 134,
#  'jessup': 135,
#  'reliable': 136,
#  'jacquelle': 82,
#  'citra': 138,
#  'kaminomoto': 139,
#  'doxa pomade': 141,
#  'kailijumei': 142,
#  'fleecy': 143,
#  'ketomed': 394,
#  'ralph lauren': 145,
#  'make over': 146,
#  'bath&body works': 147,
#  'sayota': 148,
#  'beauty creations': 149,
#  'bvlgari': 338,
#  'mirabella': 150,
#  'sharp': 151,
#  'neogen': 152,
#  'st.ives': 153,
#  'burt s bees': 154,
#  'saint laurent': 155,
#  'ryo': 156,
#  'nyx': 157,
#  'colus': 363,
#  'lucas papaw': 159,
#  'clean&clear': 160,
#  'son park': 203,
#  'jafra': 161,
#  'nars': 162,
#  'ladystar': 163,
#  'everso': 164,
#  'marcks': 165,
#  'cetaphil': 166,
#  'panasonic': 167,
#  'aigner': 290,
#  'sunsilk': 169,
#  'the caviar': 170,
#  'feves': 171,
#  'beauty blender': 172,
#  'haple': 292,
#  'beauphoria': 175,
#  'bio oil': 176,
#  'jordana': 201,
#  'pacinos': 177,
#  'some by mi': 178,
#  'bali alus': 367,
#  'a pieu': 180,
#  'dove': 181,
#  'exito pomade': 182,
#  'fanbo': 326,
#  'the wet brush': 184,
#  'casandra': 185,
#  '16 brand': 186,
#  'palmolive': 187,
#  'sophie paris': 188,
#  'zyo': 189,
#  'city color': 190,
#  'kylie cosmetics': 191,
#  'kerastase': 192,
#  'holika': 193,
#  'gse': 194,
#  'mineral botanica': 195,
#  'zoya': 273,
#  'wahl': 196,
#  'casablanca': 197,
#  'strawberry nail henna': 198,
#  'bioaqua': 199,
#  'mad for makeup': 200,
#  'carolina herrera': 372,
#  'pond s': 29,
#  'stila': 202,
#  'burberry': 354,
#  'goban': 89,
#  'luxcrime': 204,
#  'kiss proof': 62,
#  'dunhill': 206,
#  'hn original': 207,
#  'cloris': 84,
#  'bmks': 209,
#  'mise en scene': 210,
#  'smith': 211,
#  'koryu nikko': 27,
#  'j.cat beauty': 213,
#  'victoria s secret': 214,
#  'inglot': 144,
#  'artisan professionnel': 216,
#  'folti baffi': 217,
#  'freeman': 218,
#  'aura beauty': 219,
#  'oriflame': 220,
#  'mamonde': 221,
#  'safi': 222,
#  'herbal essences': 223,
#  'gove': 224,
#  'scentio': 225,
#  'lip ice': 226,
#  'tokyo night': 227,
#  'original source': 95,
#  'faylacis': 229,
#  'opi': 100,
#  'dr pure': 215,
#  'remington': 232,
#  'hugo boss': 233,
#  'bali ratih': 234,
#  'w.dressroom': 236,
#  'benefit': 237,
#  'bravas': 238,
#  'surrati': 239,
#  'aprilskin': 240,
#  'brasov': 241,
#  'sensatia botanicals': 374,
#  'garuda indonesia': 242,
#  'implora': 243,
#  'hatomugi': 244,
#  'estee lauder': 245,
#  'rimmel london': 246,
#  'skinfood': 247,
#  'hare': 248,
#  'miss rose': 331,
#  'kirin': 334,
#  'wak doyok': 251,
#  'hanasui': 252,
#  'bio herbal': 253,
#  'dorco': 254,
#  'natural pacific': 255,
#  'natulova': 256,
#  'dobha': 373,
#  'skin aqua': 258,
#  'pigeon': 261,
#  'blp': 262,
#  'venon': 263,
#  'bragg': 264,
#  'coty airspun': 265,
#  'purbasari': 266,
#  'kamalia by titi kamal': 267,
#  'bellagio': 268,
#  'namo id': 269,
#  'cathy doll': 37,
#  'theraskin': 26,
#  'armani': 272,
#  'fayolla': 174,
#  'morphe': 274,
#  'e.l.f': 64,
#  'tonymoly': 276,
#  'murray s': 277,
#  'metal fortis': 278,
#  'lucido l': 279,
#  'marina': 280,
#  'bh cosmetics': 281,
#  'pantene': 259,
#  'ever white': 283,
#  'tescom': 116,
#  'montblanc': 345,
#  'nacific': 285,
#  'babyliss': 286,
#  'master kids': 287,
#  'fleco': 288,
#  'ultra jaya': 289,
#  'jbs new york': 291,
#  'monistat': 106,
#  'davis': 293,
#  'biore': 294,
#  'gentle fever': 295,
#  'glansie': 296,
#  'hpai': 297,
#  'barbers pomade': 298,
#  'rollover reaction': 299,
#  'tabita skincare': 300,
#  'aichun': 302,
#  'nu amoorea': 303,
#  'emeron': 304,
#  'mutouch': 305,
#  'regrou': 306,
#  'clinique': 307,
#  'mediheal': 308,
#  'tresemme': 309,
#  'the bath box': 310,
#  'dermaluz': 311,
#  't.m pomade': 312,
#  'novo': 313,
#  'inez': 109,
#  'rejoice': 315,
#  'head&shoulders': 322,
#  'sulwhasoo': 317,
#  'boteng shaver': 318,
#  'dr jart': 319,
#  'senswell': 320,
#  'focallure': 321,
#  'dear me': 316,
#  'mustika ratu': 323,
#  'jeanne arthes': 324,
#  'chief pomade': 325,
#  'jergens': 327,
#  'la tulipe': 349,
#  'vienna': 328,
#  'tiens': 111,
#  'stives': 330,
#  'make up for ever': 249,
#  'heimish': 332,
#  'kiehl s': 333,
#  'esplanade': 250,
#  'cottage': 335,
#  'king pomade': 391,
#  'secret key': 337,
#  'viva': 43,
#  'ecotools': 339,
#  'benton': 340,
#  'la perle': 341,
#  'aztec': 342,
#  'crystal': 343,
#  'colab': 344,
#  'charlie': 44,
#  'zara': 346,
#  'rexona': 347,
#  'instyler': 348,
#  'batiste': 80,
#  'milani': 393,
#  'yuki': 351,
#  'liplapin': 352,
#  'the ordinary': 353,
#  'beautylabo': 355,
#  'amara': 230,
#  'l.a.girl': 358,
#  'chloe': 359,
#  'turbo': 114,
#  'cosrx': 360,
#  'esenses': 128,
#  'daeng gi meo ri': 362,
#  'fair n pink': 158,
#  'suavecito': 364,
#  'rainbow': 365,
#  'lancome': 366,
#  'calvin klein': 179,
#  'kojie san': 183,
#  'pixi': 369,
#  'love in motion': 370,
#  'furatasse': 371,
#  'nr': 301,
#  'kirkland': 270,
#  'laneige': 375,
#  'bsy': 257,
#  'liese': 377,
#  'senka': 378,
#  'nivea': 379,
#  'jennifer lopez': 380,
#  'anastasia beverly hills': 381,
#  'tezzen': 382,
#  'natrue republic': 383,
#  'gatsby': 384,
#  'miranda': 385,
#  'scream pomade': 386,
#  'matrix garuda': 387,
#  'silkygirl': 388,
#  'philips': 389,
#  'vaseline': 390,
#  'selsun': 336,
#  'crushlicious': 392,
#  'lee gee ham': 350,
#  'armando caruso': 356,
#  'studio tropik': 395,
#  'everwhite': 396,
#  'al haramain': 397,
#  'lifebuoy': 398,
#  'nasa': 399,
#  'axe': 400}

# %%
df_beauty_train = pd.read_csv('./data/beauty_data_info_train_competition.csv')

# %% [markdown]
# # Train Random Forest

# %%
def train_RF_model():
    """
    Random forest model
    """
    X_train, X_test, y_train, y_test = train_test_arrays # Unpack data


    # Preprocess each sentence in the train and test sets
    X_train, X_test = np.array([preprocessor(x) for x in X_train]), np.array([preprocessor(x) for x in X_test])

    # Build pipeline
    text_clf = Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('clf', RandomForestClassifier(n_estimators=750))])


    # Define parameters for grid search
    parameters = {'vect__ngram_range': [(1, 1), (1, 2), (1, 3)],
                'tfidf__use_idf': (True, False),}


    # Grid search across our parameters, scoring by accuracy
    gs_clf = GridSearchCV(estimator=text_clf, param_grid=parameters, cv=5, iid=False, n_jobs=-1, scoring='accuracy')
    gs_clf.fit(X_train, y_train)

    return gs_clf, X_test

# %%
df_sample
# Out:
#                                      id    tagging
# 0                    370855998_Benefits        3 2
# 1                       370855998_Brand     246 98
# 2                370855998_Colour_group      29 26
# 3             370855998_Product_texture        3 4
# 4                   370855998_Skin_type        7 7
# 5                    637234604_Benefits        4 2
# 6                       637234604_Brand    338 248
# 7                637234604_Colour_group      42 15
# 8             637234604_Product_texture        7 4
# 9                   637234604_Skin_type        5 0
# 10                   690282890_Benefits        3 0
# 11                      690282890_Brand    243 244
# 12               690282890_Colour_group      23 44
# 13            690282890_Product_texture        1 7
# 14                  690282890_Skin_type        5 0
# 15                   930913462_Benefits        0 1
# 16                      930913462_Brand    285 394
# 17               930913462_Colour_group       21 5
# 18            930913462_Product_texture        1 6
# 19                  930913462_Skin_type        2 1
# 20                  1039280071_Benefits        2 1
# 21                     1039280071_Brand     126 15
# 22              1039280071_Colour_group      29 21
# 23           1039280071_Product_texture        6 3
# 24                 1039280071_Skin_type        2 4
# 25                  1327710392_Benefits        1 2
# 26                     1327710392_Brand      47 24
# 27              1327710392_Colour_group       37 4
# 28           1327710392_Product_texture        2 7
# 29                 1327710392_Skin_type        2 5
# ...                                 ...        ...
# 1104482            955369303_Memory RAM        8 4
# 1104483                 955369303_Brand       43 5
# 1104484       955369303_Warranty Period        9 4
# 1104485      955369303_Storage Capacity      13 16
# 1104486          955369303_Color Family       24 3
# 1104487           955369303_Phone Model     3 1290
# 1104488                955369303_Camera       6 12
# 1104489     955369303_Phone Screen Size        4 3
# 1104490     1638035772_Operating System        0 6
# 1104491             1638035772_Features        1 6
# 1104492  1638035772_Network Connections        0 0
# 1104493           1638035772_Memory RAM        9 2
# 1104494                1638035772_Brand      16 44
# 1104495      1638035772_Warranty Period       13 3
# 1104496     1638035772_Storage Capacity       10 3
# 1104497         1638035772_Color Family       12 4
# 1104498          1638035772_Phone Model   613 2117
# 1104499               1638035772_Camera       11 0
# 1104500    1638035772_Phone Screen Size        1 0
# 1104501     1498091427_Operating System        2 5
# 1104502             1498091427_Features        5 6
# 1104503  1498091427_Network Connections        0 0
# 1104504           1498091427_Memory RAM        1 1
# 1104505                1498091427_Brand      51 35
# 1104506      1498091427_Warranty Period       13 7
# 1104507     1498091427_Storage Capacity      17 15
# 1104508         1498091427_Color Family      11 14
# 1104509          1498091427_Phone Model  2159 1571
# 1104510               1498091427_Camera       5 13
# 1104511    1498091427_Phone Screen Size        4 0
#
# [1104512 rows x 2 columns]

# %% [markdown]
# # Train XGBoost

# %%
df_fashion_submit = pd.DataFrame(fashion_submit_dict)

# %%
for column in beauty_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_beauty_train, column, 0.2)
    X_train = X_train.as_matrix()
    y_train = y_train.as_matrix()
    print (X_train.shape)
    model = XGBClassifier()
    model.fit(X_train[:,np.newaxis],y_train)
# Out:
# Now processing for column: Brand
# (190502,)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-2cfde8f81329> in <module>
#       7     print (X_train.shape)
#       8     model = XGBClassifier()
# ----> 9     model.fit(X_train[:,np.newaxis],y_train)
#      10
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     704         else:
#     705             train_dmatrix = DMatrix(X, label=training_labels,
# --> 706                                     missing=self.missing, nthread=self.n_jobs)
#     707
#     708         self._Booster = train(xgb_options, train_dmatrix, self.n_estimators,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     405             self._init_from_csc(data)
#     406         elif isinstance(data, np.ndarray):
# --> 407             self._init_from_npy2d(data, missing, nthread)
#     408         elif isinstance(data, DataTable):
#     409             self._init_from_dt(data, nthread)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xgboost/core.py in _init_from_npy2d(self, mat, missing, nthread)
#     477         # we try to avoid data copies if possible (reshape returns a view when possible
#     478         # and we explicitly tell np.array to try and avoid copying)
# --> 479         data = np.array(mat.reshape(mat.size), copy=False, dtype=np.float32)
#     480         self.handle = ctypes.c_void_p()
#     481         missing = missing if missing is not None else np.nan
#
# ValueError: could not convert string to float: 'nars light reflecting translucent powder'

# %%
def build_XGB_model():
    """
    Random XGBoost model
    """
    
    # Build pipeline
    text_clf = Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('xgb', XGBClassifier(n_estimators=2, silent = False, n_jobs = -1,
                                               objective = 'softmax'))])


    # Define parameters for grid search
    parameters = {'vect__ngram_range': [(1, 1), (1, 2), (1, 3)],
                'tfidf__use_idf': (True, False),
                 'xgb__learning_rate': [0.01, 0.1]}
    


    # Grid search across our parameters, scoring by accuracy
    gs_clf = GridSearchCV(estimator=text_clf, param_grid=parameters, cv=5, iid=False, n_jobs=-1, scoring='accuracy')
    gs_clf.fit(X_train, y_train)

    return gs_clf

# %%
# beauty_feature_columns = [ 'Brand', 'Colour_group', 'Benefits', 'Product_texture', 'Skin_type']

beauty_feature_columns = ['Brand']
df_beauty_train = pd.read_csv('../data/beauty_data_info_train_competition.csv')

# df_beauty_train = df_beauty_train.head(n=1500)
for column in beauty_feature_columns:
    print ("Now processing for column:", column)
    # Unpack data
    X_train,X_test,y_train,y_test = train_test_data(df_beauty_train, column, 0.2)
    XGB_model = train_test_XGB_model('beauty', column, X_train, y_train)
# Out:
# Now processing for column: Brand
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-f8019b302bbb> in <module>
#       9     # Unpack data
#      10     X_train,X_test,y_train,y_test = train_test_data(df_beauty_train, column, 0.2)
# ---> 11     XGB_model = train_test_XGB_model('beauty', column, X_train, y_train)
#
# <ipython-input-12-e505dc4a0e1a> in train_test_XGB_model(category, column, X_train, y_train)
#       1 def train_test_XGB_model(category, column, X_train, y_train):
# ----> 2     XGB_model = build_XGB_model()
#       3     XGB_model.fit(X_train, y_train)
#       4     # Evaluation
#       5     best_params = XGB_model.best_params_
#
# <ipython-input-21-6b038a86ec3e> in build_XGB_model()
#      20     # Grid search across our parameters, scoring by accuracy
#      21     gs_clf = GridSearchCV(estimator=text_clf, param_grid=parameters, cv=5, iid=False, n_jobs=-1, scoring='accuracy')
# ---> 22     gs_clf.fit(X_train, y_train)
#      23
#      24     return gs_clf
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
def train_test_XGB_model(category, column, X_train, y_train):
    XGB_model = build_XGB_model()
    XGB_model.fit(X_train, y_train)
    # Evaluation
    best_params = XGB_model.best_params_
    predicted = XGB_model.predict(X_test)
    
    # Print the score
    best_params = best_params
    print('Best Parameters: ', best_params)
    train_acc = round(XGB_model.best_score_, 2)
    print('Train Set Accuracy: ', train_acc)
    test_acc = round(np.mean(predicted == y_test), 2)
    print('Test Set Accuracy: ', test_acc)
    
    with open ('XGB_clf_09032019_DT_{}_{}.pkl'.format(category, column), 'wb') as f:
        pickle.dump(XGB_model, f)
        
    return XGB_model

# %%
df_beauty_submit = pd.DataFrame(beauty_submit_dict)

# %%
df_fashion_submit['tagging'].dtypes
# Out:
# dtype('float64')

# %%
final_submit = df_fashion_submit.append([df_mobile_submit, df_beauty_submit])

# %%
final_submit.iloc[1]['tagging']
# Out:
# '1.0 1'

# %%
for index, row in final_submit.iterrows():
    row['tagging'] = row['tagging']+" 1"

# %%
final_submit['tagging']
# Out:
# 0          3 1
# 1          1 1
# 2          1 1
# 3          0 1
# 4          8 1
# 5          0 1
# 6          8 1
# 7          8 1
# 8          1 1
# 9          3 1
# 10         0 1
# 11         1 1
# 12        13 1
# 13         8 1
# 14         8 1
# 15         3 1
# 16         8 1
# 17        13 1
# 18         1 1
# 19         1 1
# 20         8 1
# 21         3 1
# 22         1 1
# 23         1 1
# 24         8 1
# 25         8 1
# 26         1 1
# 27         3 1
# 28         8 1
# 29         8 1
#           ...
# 382695     0 1
# 382696     2 1
# 382697     0 1
# 382698     0 1
# 382699     0 1
# 382700     0 1
# 382701     0 1
# 382702     0 1
# 382703     0 1
# 382704     0 1
# 382705     0 1
# 382706     0 1
# 382707     0 1
# 382708     0 1
# 382709     2 1
# 382710     0 1
# 382711     3 1
# 382712     6 1
# 382713     0 1
# 382714     2 1
# 382715     0 1
# 382716     0 1
# 382717     4 1
# 382718     0 1
# 382719     0 1
# 382720     0 1
# 382721     0 1
# 382722     0 1
# 382723     0 1
# 382724     0 1
# Name: tagging, Length: 1174802, dtype: object

# %%
# Out:
# str

# %%
df_1 = df_mobile_train.head(n=5)
df_1.to_csv('mobile_sample.csv')

# %% [markdown]
# # TO-DO

# %%
# Check invalid RAM
