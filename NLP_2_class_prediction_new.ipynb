# %%
# Import modules
import pandas as pd
import numpy as np
import pickle
import json

# %%
# Import sklearn modules
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import SGDClassifier

# %%
from NLP.util import category_json, category_feature_columns
from NLP.util import train_test_data
from NLP.util import column_class_to_text, column_text_to_class, column_class_to_text_debug

# %%
# Pandas printing setting
desired_width=320
pd.set_option('display.width', desired_width)
pd.set_option('display.max_columns',10)
pd.set_option('display.max_colwidth', 0)

# %%
def array_to_class_list(model, result_array):
    """Return a tuple of class_1,class_2"""
    class_string_1 = str(int(model.classes_[result_array[0]]))
    class_string_2 = str(int(model.classes_[result_array[1]]))
    return class_string_1,class_string_2

# %%
def array_to_class_string(model, result_array):
    """This function takes output from load_and_predict and find out the class from SGD.classes_ method
    joint with space to fulfill the competition format"""
    class_string_1 = str(int(model.classes_[result_array[0]]))
    class_string_2 = str(int(model.classes_[result_array[1]]))
    result_string = ''
    result_string = result_string + class_string_1 + " " + class_string_2
    return result_string

# %%
def load_and_predict_beauty(df_beauty_val, n, column,X_test):
    """This is to load the pkl module and output the 2 classes"""
    # Load the model
    with open('SGD_clf_02032019_{}.pkl'.format(column), 'rb') as f:
        SGD_clf = pickle.load(f)
    # For 1 class only
    predicted = SGD_clf.predict(X_test)
    df_beauty_val[column+'1_class'] = predicted
    
    # Predict the probability for 2 classes
    result_prob = SGD_clf.predict_proba(X_test)
    result_prob_array = np.array([best_n_classes(2, i) for i in result_prob])
    result_prob_2_class = [array_to_class_string(SGD_clf, i) for i in result_prob_array]
    df_beauty_val[column] = pd.Series(result_prob_2_class)
#     for index, row in df_beauty_val.iterrows():
#         row[column] = array_to_class_string(row[column])
    
    return df_beauty_val

# %%
def load_and_predict(cat, df, n, column,X_test):
    """This is to load the pkl module and output the 2 classes"""
    # Load the model
    with open('./NLP/SGD_clf_21032019_{0}_{1}.pkl'.format(cat, column), 'rb') as f:
        SGD_clf = pickle.load(f)
    # For 1 class only
    predicted = SGD_clf.predict(X_test)
    df[column+'1_class'] = predicted
    
    # Predict the probability for 2 classes
    result_prob = SGD_clf.predict_proba(X_test)
    result_prob_array = np.array([best_n_classes(2, i) for i in result_prob])
    result_prob_2_class = [array_to_class_string(SGD_clf, i) for i in result_prob_array]
    df[column] = pd.Series(result_prob_2_class)
#     for index, row in df_beauty_val.iterrows():
#         row[column] = array_to_class_string(row[column])
    
    return df

# %%
def load_and_predict_debug(cat, df, n, column,X_test):
    """This is to load the pkl module and output the 2 classes
    This function is used for debug mode
    """
    # Load the model
    with open('./NLP/SGD_clf_21032019_{0}_{1}.pkl'.format(cat, column), 'rb') as f:
        SGD_clf = pickle.load(f)
    
    # Predict the probability for 2 classes
    result_prob = SGD_clf.predict_proba(X_test)
    result_prob_2_array = np.array([best_n_prob(2, i) for i in result_prob])
    result_class = np.array([best_n_classes(2, i) for i in result_prob])
    result_class_2_array = [array_to_class_list(SGD_clf, i) for i in result_class]
    
    class_1 = np.array([item[0] for item in result_class_2_array])
    class_2 = np.array([item[1] for item in result_class_2_array])
    
    prob_1 = np.array([item[0] for item in result_prob_2_array])
    prob_2 = np.array([item[1] for item in result_prob_2_array])
    
    df[column+'_predicted_1'] = class_1
    df[column+'_predicted_1_prob'] = prob_1
    df[column+'_predicted_2'] = class_2
    df[column+'_predicted_2_prob'] = prob_2
#     for index, row in df_beauty_val.iterrows():
#         row[column] = array_to_class_string(row[column])
    
    return df

# %%
def best_n_classes(n, full_array):
    return np.flip(np.argpartition(full_array, -n)[-n:])

# %%
def best_n_prob(n, full_array):
    return np.flip(full_array[np.argpartition(full_array, -n)[-n:]])

# %%
def check_column(df, column):
    df_check_result = df[['title', column, column+'_predicted_1']]
    df_check_result.dropna(subset = [column], inplace = True)
    df_check_result = df_check_result.loc[~(df_check_result[column] == df_check_result[column+'_predicted_1'])]
    return df_check_result

# %%
def check_column_debug(df, column):
    df_check_result = df[['title', column, column+'_predicted_1', column+'_predicted_1_prob', column+'_predicted_2', column+'_predicted_2_prob']]
    df_check_result.dropna(subset = [column], inplace = True)
    df_check_result[column] = df_check_result[column].astype(int).astype(str)
    df_check_result = df_check_result.loc[~(df_check_result[column] == df_check_result[column+'_predicted_1'])]
    return df_check_result

# %% [markdown]
# # Predict Label
#
# This section is the normal label prediction for DEBUG without compliance to competition

# %%
df_beauty_competition = pd.read_csv('./data/beauty_data_info_val_competition.csv')
df_fashion_competition = pd.read_csv('./data/fashion_data_info_val_competition 2.csv')
df_mobile_competition = pd.read_csv('./data/mobile_data_info_val_competition.csv')

# %%
df_beauty_debug = pd.read_csv('./data/beauty_data_info_train_competition.csv')
df_fashion_debug = pd.read_csv('./data/fashion_data_info_train_competition_new.csv')
df_mobile_debug = pd.read_csv('./data/mobile_data_info_train_competition.csv')

# %%
df_fashion_compare = df_fashion_debug.sample(frac=0.1)

X_compare_test = df_fashion_compare['title']
for column in category_feature_columns['fashion']:
    print ("Now comparing for column:", column)
    df_fashion_compare = load_and_predict_debug('fashion', df_fashion_compare, 2, column,X_compare_test)
# Out:
# Now comparing for column: Collar Type
# Now comparing for column: Sleeves
# Now comparing for column: Pattern
# Now comparing for column: Fashion Trend
# Now comparing for column: Clothing Material

# %%
df_pattern_check = check_column_debug(df_fashion_compare, 'Pattern')
# df_pattern_check = column_class_to_text_debug(df_pattern_check, category='fashion', column = 'Pattern')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
def column_class_to_text_debug(df, category, column):
    """This function is to convert the dataframe with only one single feature column into text
    This is used in the debugging mode
    """
    map_json = category_json[category]
    column_map = {}
    column_map[column] = {v: k for k, v in map_json[column].items()}
    df[column] = df[column].astype(int)
    df[column+'_predicted_1'] = df[column+'_predicted_1'].astype(int)
    df[column+'_predicted_2'] = df[column+'_predicted_2'].astype(int)
    df.loc[:, column] = df[column].map(column_map[column])
    df.loc[:, column+'_predicted_1'] = df[column+'_predicted_1'].map(column_map[column])
    df.loc[:, column + '_predicted_2'] = df[column + '_predicted_2'].map(column_map[column])
    return df

# %%
def check_result(df, category, column):
    df_check = check_column_debug(df, column)
    df_check = column_class_to_text_debug(df_check, category=category, column = column)
    return df_check

# %%
df_collar_check = check_result('Collar Type')
df_pattern_check = check_result('Pattern')
df_sleeves_check = check_result('Sleeves')
df_fashion_check = check_result('Fashion Trend')
df_clothing_check = check_result('Clothing Material')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_clothing_check
# Out:
#                                                                                                        title Clothing Material Clothing Material_predicted_1  Clothing Material_predicted_1_prob Clothing Material_predicted_2  Clothing Material_predicted_2_prob
# 270613  import atasan kemeja wanita lengan 3 4 putih hitam garis stripe salur                                 polyester         cotton                        0.644074                            rayon                         0.355103
# 49168   blus lengan panjang casual warna polos                                                                cotton            denim                         0.328076                            polyester                     0.315149
# 171478  sm long dress casual v neck tanpa lengan tali spaghetti warna polos untuk wanita musim panas          cotton            polyester                     0.598429                            cotton                        0.333044
# 42337   kemeja wanita casual lengan panjang model longgar motif print garis untuk musim gugur                 polyester         cotton                        0.509926                            polyester                     0.489679
# 107134  dress o neck lengan pendek sexy casual motif print                                                    cotton            polyester                     0.565620                            cotton                        0.222376
# 32321   kaos t shirt o neck lengan pendek untuk musim panas                                                   cotton            rayon                         0.372534                            polyester                     0.350602
# 248217  blus casual wanita model batwing dengan kerah crew neck dan potongan longgar warna polos              cotton            polyester                     0.411168                            denim                         0.316252
# 148801  print tied v back sleeveless sheath dress                                                             chiffon           polyester                     0.788914                            rayon                         0.142541
# 217479  blus wanita model off shoulder lengan panjang dengan potongan slim dan gambar motif ular              cotton            polyester                     0.409284                            cotton                        0.379574
# 137332  dress evelyn baju pesta mini murah lengan panjang pita sale ll                                        lace              cotton                        0.346899                            rayon                         0.258794
# 16450   bayar di tempat atasan o neck lengan panjang model backless dengan motif garis pita untuk wanita      cotton            polyester                     0.703899                            cotton                        0.296101
# 237152  tank crop top wanita sexy casual tanpa lengan model round neck print kucing untuk musim panas         cotton            polyester                     0.553546                            cotton                        0.446454
# 263199  kaos t shirt casual wanita tanpa lengan dengan kerah bulat dan potongan longgar motif floral          polyester         cotton                        0.520259                            polyester                     0.469934
# 128385  fl sexy women strap v neck a line dress bandage back single breasted flower printed summer dresses    cotton            polyester                     0.567794                            cotton                        0.413905
# 190700  dress mini asimetris o neck lengan panjang motif garis patchwork untuk wanita ada ukuran besar        cotton            polyester                     0.880034                            cotton                        0.119966
# 234165  blus casual kerah tegak lengan panjang warna polos untuk wanita                                       cotton            polyester                     0.339588                            rayon                         0.258279
# 92123   dress wanita vintage lengan panjang model round neck bodycon motif print polkadot                     cotton            polyester                     0.692275                            cotton                        0.275901
# 181058  2018 blus off shoulder sabrina longgar lengan pendek untuk musim panas                                polyester         cotton                        0.491073                            polyester                     0.412789
# 253958  kaos t shirt sexy casual model slim lengan panjang untuk wanita                                       polyester         nylon                         0.359618                            cotton                        0.339929
# 242044  blus casual longgar o neck lengan 3 4 flare hem asimetris warna polos                                 polyester         rayon                         0.496279                            polyester                     0.311946
# 42933   kaos crop top v neck lengan panjang sexy                                                              polyester         cotton                        0.391627                            velvet                        0.299223
# 193641  bayar di tempat kemeja wanita casual lengan panjang model v neck untuk kantor                         chiffon           net                           0.401212                            polyester                     0.299431
# 105498  dress v neck lengan pendek model lipit dengan pita kancing untuk wanita                               cotton            polyester                     0.782355                            cotton                        0.111305
# 52394   new polo country c6 38 original kaos kerah cewek cotton hijau q87                                     cotton            poly cotton                   0.501905                            cotton                        0.498095
# 194006  v neck loose fit floral printed ruffle casual three quarter sleeve shirt blouse                       cotton            polyester                     0.528542                            cotton                        0.316860
# 219646  crop top sexy tanpa lengan motif bordir hati                                                          polyester         cotton                        0.627595                            polyester                     0.372405
# 154678  maxi cape ayuka                                                                                       satin             silk                          0.350405                            cotton                        0.206281
# 125826  bellemoda dress maxi deep v neck casual dengan belahan samping untuk pesta cocktail                   lace              polyester                     0.480262                            cotton                        0.270067
# 230139  hooded zipper sport best 1pc shirt patchwork female                                                   polyester         cotton                        0.696765                            polyester                     0.264218
# 229405  blus tunik asimetris v neck lengan panjang untuk wanita ada ukuran besar                              polyester         rayon                         0.309647                            polyester                     0.260916
# 217277  dress import tribal retro wrap v neck midi blue 3 4 sleeve lutut biru                                 polyester         cotton                        0.522215                            polyester                     0.387821
# 16100   t shirt open back backless tee v neck tie up sexy casual stripe tops                                  polyester         cotton                        0.785156                            polyester                     0.209167
# 49382   co blus casual model off shoulder longgar lengan panjang motif bunga untuk wanita                     polyester         cotton                        0.522325                            polyester                     0.362960
# 241090  dijual murah grosir polo shirt couple polos bestseller                                                polyester         cotton                        0.464625                            jersey                        0.205867
# 166038  dress bodycon mini casual model lengan pendek motif print camo untuk wanita pantai musim panas        polyester         cotton                        0.515533                            polyester                     0.484467
#
# [1619 rows x 6 columns]

# %%
# Randomly sample some data

df_beauty_compare = df_beauty_debug.sample(frac=0.1) 

X_compare_test = df_beauty_compare['title']
for column in category_feature_columns['beauty']:
    print ("Now comparing for column:", column)
    df_beauty_compare = load_and_predict_debug('beauty', df_beauty_compare, 2, column,X_compare_test)

# df_beauty_compare = df_beauty_train.sample(frac=0.1) 

# X_compare_test = df_beauty_compare['title']
# for column in category_feature_columns['beauty']:
#     print ("Now comparing for column:", column)
#     with open('./NLP/model/SGD_clf_21032019_{}.pkl'.format(column), 'rb') as f:
#         SGD_clf = pickle.load(f)
#     predicted = SGD_clf.predict(X_compare_test)
#     df_beauty_compare[column+'_predicted'] = predicted
# Out:
# Now comparing for column: Brand
# Now comparing for column: Colour_group
# Now comparing for column: Benefits
# Now comparing for column: Product_texture
# Now comparing for column: Skin_type

# %%
df_beauty_competition
# Out:
#            itemid                                                                                         title                                         image_path
# 0      370855998   flormar 7 white cream bb spf 30 40ml                                                          beauty_image/1588591395c5a254bab84042005f2a9f.jpg
# 1      637234604   maybelline clear smooth all in one bb cream spf 21                                            beauty_image/920985ed9587ea20f58686ea74e20f93.jpg
# 2      690282890   murah innisfree eco natural green tea bb cream spf25 pa eksklusif                             beauty_image/90b40e5710f54352b243fcfb0f5d1d7f.jpg
# 3      930913462   loreal white perfect day cream spf 17 pa whitening+even tone murah                            beauty_image/289c668ef3d70e1d929d602d52d5d78a.jpg
# 4      1039280071  hada labo cc cream ultimate anti aging spf 35 pa 25gr pilih warna                             beauty_image/d5b3e652c5822d2306f4560488ec30c6.jpg
# 5      1327710392  cathy doll cc speed white powder pact spf 40 original 100                                     beauty_image/e1e50828d5594721a7d5d5c1ff78afbd.jpg
# 6      1328802799  safi white natural brightening cream 45g                                                      beauty_image/97ec852d5afc5d82ac02b80083cf292f.jpg
# 76538  1823139406  promo nivea made in germany hydro care lip balm termurah                                      beauty_image/1259bddfe71932d34c503d12269b3dc8.jpg
# 76539  1824884851  makeover liquid lip color                                                                     beauty_image/a4f765ab4f320eccb1dc60fa540d6db4.jpg
# 76540  1826670507  lip cream wardah                                                                              beauty_image/5910b3379e4ad845a7be914b6cb02527.jpg
# 76541  1832111687  la tulipe stay matte lip cream 08                                                             beauty_image/e8022625c508a528dbd6c90869a0bc2a.jpg
# 76542  1832269907  etude house berry delicious color in liquid lips juicy sample                                 beauty_image/3af512eb5a3c8b0632d787110bcb796b.jpg
# 76543  1832929407  goban matte liquid lipstick                                                                   beauty_image/e07d7b1400f51a09260040143b969306.jpg
# 76544  1833165562  nivea lip balm                                                                                beauty_image/d592906ac8f906bc36664e906f635619.jpg
#
# [76545 rows x 3 columns]

# %%
df_brand_check = check_result(df_beauty_compare, 'beauty','Brand')
df_colour_check = check_result(df_beauty_compare,'beauty','Colour_group')
df_benefits_check = check_result(df_beauty_compare,'beauty','Benefits')
df_product_check = check_result(df_beauty_compare,'beauty','Product_texture')
df_skin_check = check_result(df_beauty_compare,'beauty','Skin_type')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_colour_check
# Out:
#                                                                                       title       Colour_group Colour_group_predicted_1  Colour_group_predicted_1_prob Colour_group_predicted_2  Colour_group_predicted_2_prob
# 66583   wardah instaperfect bb cushion 13 beige                                              emas               8 color                  0.452947                       1 warna                  0.334817
# 155433  wardah white secret night cream                                                      1 warna            9 color                  0.833938                       1 warna                  0.166062
# 68555   revlon new complexion two way foundation medium beige                                maroon             emas                     0.347076                       maroon                   0.346553
# 99554   bedak ertos                                                                          maroon             emas                     0.583653                       maroon                   0.416347
# 182915  etude house zero sebum drying powder                                                 maroon             1 warna                  0.896801                       maroon                   0.052956
# 48081   viva compact powder kuning langsat                                                   emas               1 warna                  0.665024                       emas                     0.298546
# 192179  innisfree water fit cushion with case preloved                                       emas               8 color                  0.510781                       emas                     0.405857
# 242738  etude house baking powder crunch pore scrub                                          emas               1 warna                  0.507306                       emas                     0.492694
# 82702   etude house precious mineral bb cream                                                1 warna            8 color                  0.573909                       1 warna                  0.364513
# 112246  innisfree no sebum mineral powder                                                    emas               1 warna                  0.420462                       warna merah cabai        0.335202
# 99859   cetaphil moisturizing cream 100g terlaris                                            emas               maroon                   0.453568                       emas                     0.428330
# 275058  16 warna lipstick lip gloss cair matte                                               1 warna            maroon                   0.422179                       1 warna                  0.352055
# 151439  secret key let me know cc cream spf50 pa                                             8 color            1 warna                  0.608715                       8 color                  0.367824
# 125473  diskon sulwhasoo perfecting cushion brightening set+1 refill spf50 pa make up wajah  8 color            emas                     0.923777                       1 warna                  0.076223
# 195151  maybelline bb cushion matte                                                          8 color            emas                     0.957599                       1 warna                  0.042401
# 106077  limited stock ponds bb magic powder pinkish white glow                               1 warna            emas                     0.390853                       1 warna                  0.348450
# 8842    maybelline super bb cushion promo                                                    maroon             emas                     0.649612                       1 warna                  0.302331
# 100691  maybeline bb cushion                                                                 8 color            1 warna                  0.698057                       8 color                  0.232372
# 63452   peripera ink lasting cushion                                                         maroon             emas                     0.600118                       maroon                   0.363217
# 220840  neogen white truffle laycure oil stick                                               9 color            maroon                   0.468791                       warna merah cabai        0.410512
# 56630   press powder jafra                                                                   1 warna            emas                     0.789621                       1 warna                  0.210379
# 97410   preloved bedak maybelline fit me                                                     1 warna            emas                     0.534593                       1 warna                  0.465407
# 184882  innisfree no sebum mineral powder 5g                                                 1 warna            warna merah cabai        0.658092                       1 warna                  0.293075
# 115737  two way cake zoya cosmetics                                                          maroon             1 warna                  0.689725                       warna merah cabai        0.157103
# 239708  llp 823 maybelline fit me matte poreless powder                                      emas               1 warna                  0.801412                       emas                     0.198588
# 273310  nyx soft matte lip cream                                                             emas               maroon                   1.000000                       8 color                  0.000000
# 71374   emina beauty bliss bb cream                                                          emas               8 color                  0.612569                       1 warna                  0.230560
# 27982   make over powerstay mattifying transparent powder                                    emas               warna merah cabai        0.717048                       emas                     0.193965
#
# [685 rows x 6 columns]

# %%
df_brand_check
# Out:
#                                                                                                        title          Brand  Brand_predicted
# 104     krim kecantikan untuk muka mata bentuk cair mencerahkan dengan kombinasi kontur xiu yan               etude house    benefit
# 144349  ready elf e.l.f cosmetics blush palette light powder 0.56 oz 16 gr g 16gr                             e.l.f          random
# 263349  lipstick keren tahan lama dengan pelembab                                                             benefit        selection
# 152498  nortshow lipgloss cair warna matte tahan lama                                                         the balm       benefit
# 221184  acne glowing htcdh cream malam                                                                        theraskin      random
# 273149  bayar di tempat lip liquid lipstick matte pensil tahan lama anti air makeup kacantikan                the balm       benefit
# 162574  precious flower bb cream spf 30 pa                                                                    benefit        crystal
# 73418   erha acne face powder                                                                                 wardah         erto s
# 120627  animal face mask deep moisturizing sheet oil control brighten skin for woman panda tiger              bioaqua        ultra jaya
# 42310   promo smashbox hydrating under eye primer 5ml mini size                                               benefit        ultra jaya
# 89173   la girl pro concealer light ivory                                                                     random         l.a.girl
# 3958    clean face oil control bb cream                                                                       the face shop  random
# 147888  colagen cream super qualiti original                                                                  everwhite      hn original
# 89710   concealer highlighter cair sexy warna shimmer                                                         ultra jaya     benefit
# 5801    concealer foundation cair tahan lama                                                                  focallure      ultra jaya
# 19280   2mc6 cc cream matte beige zsc xalc                                                                    bioaqua        random
# 120489  bayar di tempat primer gel minyak pelembab 6ml warna transparan untuk menyamarkan porti pori          ultra jaya     benefit
# 255450  termurah silky girl natural brow pensil alis                                                          random         silkygirl
# 45396   baru april skin magic snow black cushion spf50 pa                                                     cetaphil       aprilskin
# 49311   acne white 0 1 htcd                                                                                   theraskin      random
# 157960  la girl pro bb cream shade neutral                                                                    chanel         l.a.girl
# 211117  becca soft light blurring powder                                                                      ultra jaya     random
# 259707  bayar di tempat lipstick korea matte tahan lama dengan pelembab                                       3ce            selection
# 56657   cathy doll la vie en fleur luminius flora bb cream spf30 pa                                           cathy doll     jennifer lopez
# 219856  foccalure liquid foundation waterproof                                                                wardah         benefit
# 106551  acne cream                                                                                            theraskin      everwhite
# 86328   elf essential all over cover stick original make up primer honey                                      make over      e.l.f
# 112192  skin79 super b.b crem                                                                                 burberry       random
# 10000   krim foundation kualitas bagus natural                                                                benefit        random
# 266494  5pcs lipstick matte anti air tahan lama dengan pelembab                                               ultra jaya     selection
# ...                                                         ...                                                      ...           ...
# 260317  cuci gudang silky girl magic pink lip balm lips                                                       random         silkygirl
# 113430  kat von d shade light contour palette                                                                 random         selection
# 120101  dermacol make up cover spf 30 waterproof coverage makeup                                              chanel         random
# 168984  tulljye day night cream 10 g isi 1 set siang dan malam hijau super                                    amara          random
# 192048  bayar di tempat sace lady face base primer makeup liquid smooth fine line oil control brighten        champagne      benefit
# 99025   immortal cc cream blushing pink kecantikan makeup bb wajah kosmetik                                   jafra          benefit
# 252913  bayar di tempat highlighter cair warna shimmer                                                        benefit        champagne
# 148797  magic plus white cream sachet                                                                         ultra jaya     yuki
# 275470  lipstick cair matte anti air tahan lama                                                               ultra jaya     selection
# 107745  berkualitas j.cat beauty aura glow liquid highlighter crystal sand termurah promo bulan ini           crystal        j.cat beauty
# 147554  mac studio fix fluid foundation spf 15                                                                chanel         random
# 50734   special promo e.l.f studio blush palette light free ongkir                                            e.l.f          random
# 7098    harga special kakak cc cream fain n pink                                                              ultra jaya     fair n pink
# 169118  too faced love light highlighter original reject sephora                                              random         champagne
# 50732   murah cream babypink hn 30gr original tas plastik merah                                               random         hn original
# 35187   grosir rivera two way cake 01 light oriental                                                          bioaqua        random
# 233201  bayar di tempat girl 9 colors natural beauty blush powder palette                                     focallure      benefit
# 263248  lipstick matte melembabkan tahan lama                                                                 crystal        novo
# 119140  bayar di tempat highlighter cair kosmetik makeup warna shimmer metalik                                ultra jaya     champagne
# 213252  stock terbatas skincare tiens spirulina vitaline penghilang jerawat flek hitam kerutan masalah wajah  tiens          random
# 281630  kissproof lipstick matte tahan lama melembabkan                                                       make over      benefit
# 54306   april skin magic snow fixing foundation spf 30 original make up wajah                                 random         aprilskin
# 153199  termurah bareminerals original foundation broad spectrum spf 15                                       random         selection
# 257059  kazi lan lipstick tahan lama anti air melembabkan bibir dengan 18 pilihan warna                       onyx           benefit
# 2695    the yeon cmk blemish cc stick                                                                         cosrx          the balm
# 141469  best e l f contouring blush and bronzing powder paling murah                                          e.l.f          catrice
# 230779  bedak ver 88 bounce up pact original free lipbalm hare arab                                           hare           random
# 78402   murah di shopee maya onyx shampoo cat rambut black box isi 5 packs qr0299                             onyx           kylie cosmetics
# 19007   promo cream deoonard gold silver spesial                                                              random         burberry
# 201855  ori green tea essence eye cream mata panda laoshiya                                                   wardah         random
#
# [85 rows x 3 columns]

# %%
def column_class_to_text(df, category, column):
    """This function is to convert the dataframe with only one single feature column into text
    This is used in the debugging mode
    """
    print("This function is god damn called")
    map_json = category_json[category]
    column_map = {}
    column_map[column] = {v: k for k, v in map_json[column].items()}
    df.loc[:, column] = df[column].map(column_map[column])
    df.loc[:, column+'_predicted'] = df[column+'_predicted'].map(column_map[column])
    return df

# %% [markdown]
# # Competition predict
#
# Comply to competition standard

# %%
# For beauty
beauty_feature_columns = ['Brand', 'Colour_group', 'Benefits', 'Product_texture', 'Skin_type']

#df_beauty_compare = pd.DataFrame()
X_test = df_beauty_competition['title']

for column in beauty_feature_columns:
    
    print("Now processing for column:", column)
    df_beauty_val = load_and_predict('beauty',df_beauty_competition, 2, column, X_test)
# Out:
# Now processing for column: Brand
# Now processing for column: Colour_group
# Now processing for column: Benefits
# Now processing for column: Product_texture
# Now processing for column: Skin_type

# %%
def get_title(df):
    return df['title']

def get_img_column(df):
    return df.loc[:, df.columns.str.contains('^img')]

def get_non_title(df):
    '''Select all other feature columns'''
    return df.loc[:, ~df.columns.str.contains('^img')].drop(columns = ['title'])

# %%
# For fashion

fashion_feature_columns = ['Collar Type', 'Sleeves', 'Pattern', 'Fashion Trend', 'Clothing Material']

X_test = df_fashion_competition['title']

for column in fashion_feature_columns:
    print("Now processing for column:", column)
    df_fashion_val = load_and_predict('fashion', df_fashion_competition, 2, column, X_test)
# Out:
# Now processing for column: Collar Type
# Now processing for column: Sleeves
# Now processing for column: Pattern
# Now processing for column: Fashion Trend
# Now processing for column: Clothing Material

# %%
df_fashion_competition
# Out:
#             itemid                                                                                               title  Pattern  Collar Type  Sleeves  Fashion Trend  Clothing Material                                      image_path
# 0       2282553     retro floral dress                                                                                  2.0      9999.0       9999.0   3.0            9999.0             fashion_image/78d17fdb159bba51a4250dc3d583245e
# 1       13822218    dress floral sifon                                                                                  2.0      9999.0       9999.0   9999.0         4.0                fashion_image/2f77dac9965bbfdb03cbd3724b3552c5
# 2       33555935    korean white chiffon collar dress                                                                   9999.0   13.0         9999.0   10.0           4.0                fashion_image/6dbe2e7cba5ddbb750d2144d8f248f11
# 3       65755120    women s trendy apricot o neck solid chiffon blouse lbed                                             9999.0   3.0          9999.0   9999.0         4.0                fashion_image/dc9b21429604148fc0342d12694f3294
# 4       65857438    big sale baju gamis pesta india aysilla pancar maxidress full bordir jersey real pict               9999.0   9999.0       9999.0   6.0            17.0               fashion_image/6c25c578dd8edce742a805f891f1a51f
# 5       69593037    bayar di tempat bodycon dress tanpa lengan dengan hiasan renda untuk wanita                         9999.0   9999.0       0.0      9999.0         3.0                fashion_image/17d11c0e9d7f915dc8ca9b443a336701
# 6       79488636    gaun mini pesta malam patchwork tanpa punggung lengan panjang leher v ramping seksi fashion wanita  5.0      8.0          3.0      6.0            9999.0             fashion_image/e25977681e7ebfa815efef8087ea8fd7
# 7       81622997    gaun pesta kasual wanita bergaya tanpa lengan baju siang kotak bodycon paket hip                    1.0      3.0          0.0      6.0            7.0                fashion_image/492f80d9bdfd1e412aab0873cf172cec
# 8       81743165    gaun mini diatas lutut wanita bergaya leher o lengan pendek                                         9999.0   3.0          2.0      9999.0         7.0                fashion_image/d74f56b21601a41710d72f887d6439b4
# 9       82512933    gaun pesta cardi velvet emboss payet                                                                9999.0   9999.0       9999.0   6.0            2.0                fashion_image/ee05d8051e800cc4845b5cbfae86474e
# 10      97941915    fashion wanita dress pesta seksi dengan renda putih tanpa lengan                                    9999.0   9999.0       0.0      6.0            3.0                fashion_image/7e885a3310d901880bd33e280feedf62
# 11      106988064   1110 bkk mozaic dress swan collar 100 bhn linen print aplikasi kerah fit to xl                      14.0     9999.0       9999.0   9999.0         9.0                fashion_image/1f3995ce2d6afb936ab7d61a50e44dca
# 219689  1536100948  komalshop polo basic                                                                                9999.0   13.0         9999.0   4.0            5.0                fashion_image/6f2412760fdc3538acc2fc7f6b8c64a2
# 219690  1536706218  blus elegan casual model v neck lengan panjang longgar bahan sifon untuk wanita                     18.0     8.0          3.0      9999.0         4.0                fashion_image/e7ce3e1dfa4278a7d90bfd237793b752
# 219691  1537608206  korean style kaos rajut lengan panjang wanita casual                                                9999.0   9999.0       3.0      10.0           7.0                fashion_image/8f64c84e3ea0f28fbc14dc1abbb849eb
# 219692  1538250545  musim gugur berjajar blus lengan panjang 2018 baru korea polo baris gesper pingg                    9999.0   13.0         3.0      9999.0         9999.0             fashion_image/012f7c34a0ed19d79279bdbefc9e7ee7
# 219693  1540111769  blus wanita lengan pendek model vintage motif print bunga warna hijau untuk musim panas             14.0     9999.0       2.0      3.0            9999.0             fashion_image/ceece2d2fa5a20006eedffe9e9514c4b
# 219694  1541752996  nfw blus casual wanita lengan panjang dengan bahan katun hiasan renda dan potongan longgar          18.0     9999.0       3.0      9999.0         3.0                fashion_image/51f4cd1eed69b85fd7532ec8fd5123fd
# 219695  1542015519  nfw kaos t shirt o neck lengan pendek motif buah es krim untuk wanita                               18.0     3.0          2.0      9999.0         9999.0             fashion_image/9ff69cb125d38822df1eae110f6be2ca
# 219696  1542526316  baju kaos tshirt polos casual harian wanita cewek katun cotton                                      6.0      9999.0       9999.0   9999.0         18.0               fashion_image/65654718e1f0f609fe575295815143ae
# 219697  1542627872  dress wanita lengan panjang model v neck flare untuk musim gugur dingin                             9999.0   8.0          3.0      9999.0         18.0               fashion_image/9d5f54598e095ce470ba4bea27bda900
# 219698  1542727156  dress model lengan ruffle square neck motif print gaya eropa amerika untuk wanita                   14.0     10.0         9999.0   9999.0         9999.0             fashion_image/1179f5f2eb7ecbdada80e2094b1cc1fc
# 219699  1545762961  kemeja sifon retro klasik casual motif polkadot dengan kancing untuk wanita                         9.0      8.0          9999.0   3.0            4.0                fashion_image/e7a4842745aecbea40c7f519e4ed2e53
# 219700  1546410878  kaos wanita baju polos v neck atasan kami1312                                                       6.0      8.0          9999.0   9999.0         9999.0             fashion_image/393beb3b589c6bf98f6d4b118b4feea6
# 219701  1547454381  blouse jumbo xl fit xxl kelen spandek rayon brokat good qualit                                      15.0     9999.0       9999.0   9999.0         16.0               fashion_image/93049628c669658277a3de565494571b
#
# [219702 rows x 8 columns]

# %%
# For mobile

mobile_feature_columns = ['Operating System', 'Features',
       'Network Connections', 'Memory RAM', 'Brand', 'Warranty Period',
       'Storage Capacity', 'Color Family', 'Phone Model', 'Camera',
       'Phone Screen Size']

X_test = df_mobile_competition['title']

for column in mobile_feature_columns:
    print("Now processing for column:", column)
    df_mobile_val = load_and_predict('mobile', df_mobile_competition, 2, column, X_test)
# Out:
# Now processing for column: Operating System
# Now processing for column: Features
# Now processing for column: Network Connections
# Now processing for column: Memory RAM
# Now processing for column: Brand
# Now processing for column: Warranty Period
# Now processing for column: Storage Capacity
# Now processing for column: Color Family
# Now processing for column: Phone Model
# Now processing for column: Camera
# Now processing for column: Phone Screen Size

# 160303  mobile_image/7887fdf0b7fbdb2e0454eeff21a9dc2d.jpg              6 1
# 160304  mobile_image/6816283b360b72419334d77e036828f5.jpg              6 1
# 160305  mobile_image/23cbe7cb66eaaf033844e158d9370203.jpg              6 1
# 160306  mobile_image/46d04ca50bcda8a0b2e253a1a8ef1f12.jpg              6 1
# 160307  mobile_image/72e9a658d18896857bad42ce5cec2495.jpg              1 6
# 160308  mobile_image/a1ecbf5fda6b7b151651f4fd10949a24.jpg              6 1
# 160309  mobile_image/ef6f37a6bc966b9f58e77ef916502d9b.jpg              6 1
# 160310  mobile_image/e7a56bc222c2d99c61e88c7d17bc00b6.jpg              6 1
# 160311  mobile_image/92e3358d1af6eb3a7e3d254f9a658f2c.jpg              6 1
# 160312  mobile_image/106b2fe386fd9285361f4fee6168ba1b.jpg              1 6
# 160313  mobile_image/77fabce33d6dd0808c5478540ba0f570.jpg              6 1
# 160314  mobile_image/d641a6a2e31ad3b5a784e32bbd885281.jpg              6 1
# 160315  mobile_image/12d058a4dd8a75243f97708579e9490a.jpg              6 1
# 160316  mobile_image/5059fe330dba1c15b11ca68ecc665d45.jpg              6 1
# 160317  mobile_image/ceb1dc60cfdb8213cd4995d07d347dd0.jpg              6 1
# 160318  mobile_image/4537948c85075ae28c5557c7ce8adddd.jpg              6 1
# 160319  mobile_image/366e823343f347e5917e0ca6ae7902fd.jpg              6 1
# 160320  mobile_image/4f07fd3529a5b44e95a3646291fa00f7.jpg              1 6
# 160321  mobile_image/af2ce434de94ce997c9960dd7c6d3420.jpg              6 1
# 160322  mobile_image/360104cd7006c0aa7c9365312ae40501.jpg              1 6
# 160323  mobile_image/4bd23a85f190ca5d416904a709274b1e.jpg              1 6
# 160324  mobile_image/2bbbf3ed6fcfa0480278ea1b50557ac4.jpg              6 1
# 160325  mobile_image/70e0d8ddd69692b0f134498efbddf4e1.jpg              6 1
# 160326  mobile_image/d58393fe029ba62160d2a5d1fa6638a1.jpg              6 1
# 160327  mobile_image/bfacb3c9af2f6a597008e57fb2d34609.jpg              6 1
# 160328  mobile_image/42d74ab8212a24720d42e84c649ab488.jpg              6 1
# 160329  mobile_image/0b10f33a67ccb4ee3e1240d44c2ee0ef.jpg              6 1
#
#        Features Network Connections Memory RAM  Brand Warranty Period  \
# 0           0 2                 0 2        9 3   2 18           13 11
# 1           2 0                 2 0        8 9   2 18            3 13
# 2           5 2                 2 1        9 2  43 18            13 5
# 3           5 2                 1 3        3 8  43 18            13 5
# 4           0 6                 0 3        6 9  38 18           13 11
# 5           0 1                 0 3        5 9  33 19            13 3
# 6           5 2                 1 3        3 8  43 18            13 5
# 7           0 2                 0 3        3 2   2 18            13 5
# 8           0 5                 1 2        5 6   51 2            2 13
# 9           5 2                 1 3        6 8  43 18            13 5
# 10          0 2                 3 0        3 7  43 18            13 1
# 11          0 2                 0 3        3 2  43 18            13 5
# 12          2 5                 0 2        9 2   2 18            5 13
# 13          0 5                 0 2        6 9   41 2            13 5
# 14          0 5                 0 3        3 8  43 18           13 10
# 15          0 5                 2 1        3 6  51 55            13 2
# 16          4 0                 0 3        7 5  33 19            13 3
# 17          4 0                 2 0        9 6   2 18            3 13
# 18          0 4                 0 2        9 7   2 18            13 5
# 19          4 0                 0 3        8 9   2 18            13 3
# 20          2 5                 0 2        9 2   2 18            13 5
# 21          5 4                 1 0        3 6  30 55            13 5
# 22          5 0                 0 3        3 2  43 18           13 11
# 23          3 4                 0 2        3 2  43 18           13 11
# 24          0 1                 0 2        9 8   2 18           11 13
# 25          4 2                 0 2        9 6   2 18           13 11
# 26          0 2                 0 3        3 2  43 18            3 13
# 27          5 4                 1 2        3 6  12 55           13 11
# 28          4 2                 0 2        6 9   2 18             1 3
# 29          2 5                 1 0        8 6  43 18           11 13
# ...         ...                 ...        ...    ...             ...
# 160300      5 2                 0 3        6 9  55 18           10 13
# 160301      4 6                 2 0        3 5   43 2           10 13
# 160302      1 6                 1 3        3 5   7 43           13 11
# 160303      2 4                 1 3        3 5   7 55            13 5
# 160304      4 0                 0 3        9 6  17 33           13 11
# 160305      4 5                 0 1        7 3  43 18            13 5
# 160306      4 5                 0 2        7 3  43 18           13 11
# 160307      1 4                 0 1        9 6   2 55            13 5
# 160308      0 4                 2 0        4 7  43 18            3 13
# 160309      0 1                 0 3        7 6  41 30           11 13
# 160310      4 2                 0 3        5 4  55 18            13 5
# 160311      0 2                 0 1        5 4  41 38           13 11
# 160312      6 0                 2 0        8 9   2 18            13 5
# 160313      5 2                 1 2        1 3  30 55            13 5
# 160314      2 0                 0 3        6 4  43 18            13 5
# 160315      4 0                 0 3        9 5  55 22            13 5
# 160316      0 4                 0 3        4 2  33 19           13 11
# 160317      4 0                 2 0        7 5  38 55            13 2
# 160318      4 0                 0 3        5 7  38 33            13 5
# 160319      0 4                 0 1        4 5  43 18            13 2
# 160320      2 1                 0 3        9 2    2 0           11 13
# 160321      4 0                 0 3        6 9  43 18            13 5
# 160322      4 2                 0 3        9 4   2 18           11 13
# 160323      0 2                 0 2        6 7   2 18           11 13
# 160324      0 4                 0 3        4 2  43 46            13 5
# 160325      0 4                 0 3        4 9  33 19           11 13
# 160326      5 0                 0 3        9 5    2 0           13 11
# 160327      0 4                 0 3        5 1  33 19           13 11
# 160328      0 5                 0 3        0 3  43 18           13 11
# 160329      5 0                 0 2        7 4  55 18            13 5
#
#        Storage Capacity            ...            Features1_class  \
# 0                  12 3            ...                        0.0
# 1                  3 16            ...                        2.0
# 2                  12 4            ...                        5.0
# 3                 10 12            ...                        5.0
# 4                  12 1            ...                        0.0
# 5                  12 3            ...                        0.0
# 6                 10 12            ...                        5.0
# 7                 12 16            ...                        0.0
# 8                  12 3            ...                        0.0
# 9                  10 1            ...                        5.0
# 10                16 12            ...                        0.0
# 11                 1 12            ...                        0.0
# 12                 12 3            ...                        2.0
# 13                 12 3            ...                        0.0
# 14                 1 12            ...                        0.0
# 15                13 12            ...                        0.0
# 16                 12 4            ...                        4.0
# 17                 3 16            ...                        4.0
# 18                 12 3            ...                        0.0
# 19                 12 4            ...                        4.0
# 20                 12 3            ...                        2.0
# 21                12 16            ...                        5.0
# 22                12 16            ...                        5.0
# 23                 12 3            ...                        3.0
# 24                 16 3            ...                        0.0
# 25                 12 4            ...                        4.0
# 26                12 16            ...                        0.0
# 27                 12 3            ...                        5.0
# 28                 3 16            ...                        4.0
# 29                 12 3            ...                        2.0
# ...                 ...            ...                        ...
# 160300             12 4            ...                        5.0
# 160301             3 12            ...                        4.0
# 160302             13 3            ...                        1.0
# 160303             13 3            ...                        2.0
# 160304             1 12            ...                        4.0
# 160305             12 3            ...                        4.0
# 160306             12 4            ...                        4.0
# 160307            12 16            ...                        1.0
# 160308             3 12            ...                        0.0
# 160309             12 1            ...                        0.0
# 160310             3 16            ...                        4.0
# 160311             12 1            ...                        0.0
# 160312             12 1            ...                        6.0
# 160313            10 12            ...                        5.0
# 160314             3 12            ...                        2.0
# 160315             3 16            ...                        4.0
# 160316              1 3            ...                        0.0
# 160317             12 3            ...                        4.0
# 160318             3 16            ...                        4.0
# 160319             3 16            ...                        0.0
# 160320             12 3            ...                        2.0
# 160321             12 4            ...                        4.0
# 160322              1 3            ...                        4.0
# 160323             3 16            ...                        0.0
# 160324              1 3            ...                        0.0
# 160325             3 16            ...                        0.0
# 160326             12 3            ...                        5.0
# 160327             3 16            ...                        0.0
# 160328             16 1            ...                        0.0
# 160329            12 16            ...                        5.0
#
#        Network Connections1_class Memory RAM1_class Brand1_class  \
# 0                             0.0               9.0          2.0
# 1                             2.0               8.0          2.0
# 2                             2.0               9.0         43.0
# 3                             1.0               3.0         43.0
# 4                             0.0               6.0         38.0
# 5                             0.0               5.0         33.0
# 6                             1.0               3.0         43.0
# 7                             0.0               3.0          2.0
# 8                             1.0               5.0         51.0
# 9                             1.0               6.0         43.0
# 10                            3.0               3.0         43.0
# 11                            0.0               3.0         43.0
# 12                            0.0               9.0          2.0
# 13                            0.0               6.0         41.0
# 14                            0.0               3.0         43.0
# 15                            2.0               3.0         51.0
# 16                            0.0               7.0         33.0
# 17                            2.0               9.0          2.0
# 18                            0.0               9.0          2.0
# 19                            0.0               8.0          2.0
# 20                            0.0               9.0          2.0
# 21                            1.0               3.0         30.0
# 22                            0.0               3.0         43.0
# 23                            0.0               3.0         43.0
# 24                            0.0               9.0          2.0
# 25                            0.0               9.0          2.0
# 26                            0.0               3.0         43.0
# 27                            1.0               3.0         12.0
# 28                            0.0               6.0          2.0
# 29                            1.0               8.0         43.0
# ...                           ...               ...          ...
# 160300                        0.0               6.0         55.0
# 160301                        2.0               3.0         43.0
# 160302                        1.0               3.0          7.0
# 160303                        1.0               3.0          7.0
# 160304                        0.0               9.0         17.0
# 160305                        0.0               7.0         43.0
# 160306                        0.0               7.0         43.0
# 160307                        0.0               9.0          2.0
# 160308                        2.0               4.0         43.0
# 160309                        0.0               7.0         41.0
# 160310                        0.0               5.0         55.0
# 160311                        0.0               5.0         41.0
# 160312                        2.0               8.0          2.0
# 160313                        1.0               1.0         30.0
# 160314                        0.0               6.0         43.0
# 160315                        0.0               9.0         55.0
# 160316                        0.0               4.0         33.0
# 160317                        2.0               7.0         38.0
# 160318                        0.0               5.0         38.0
# 160319                        0.0               4.0         43.0
# 160320                        0.0               9.0          2.0
# 160321                        0.0               6.0         43.0
# 9                    559.0            6.0                       4.0
# 10                  2120.0            9.0                       0.0
# 11                   716.0            2.0                       1.0
# 12                   176.0            9.0                       0.0
# 13                    39.0            5.0                       0.0
# 14                   716.0            2.0                       3.0
# 15                  1753.0            2.0                       2.0
# 16                   376.0            9.0                       0.0
# 17                  1208.0            2.0                       0.0
# 18                   178.0            1.0                       0.0
# 19                  1402.0            5.0                       1.0
# 20                  1526.0            5.0                       4.0
# 21                    94.0           12.0                       5.0
# 22                   715.0            2.0                       0.0
# 23                  1889.0            2.0                       5.0
# 24                  1482.0            6.0                       5.0
# 25                   176.0            6.0                       0.0
# 26                   715.0            2.0                       0.0
# 27                   835.0            2.0                       2.0
# 28                  1208.0            2.0                       0.0
# 29                  1477.0            6.0                       3.0
# ...                    ...            ...                       ...
# 160300               832.0            9.0                       2.0
# 160301              1479.0            1.0                       2.0
# 160302              1580.0            3.0                       3.0
# 160303                33.0            6.0                       0.0
# 160304               661.0            9.0                       5.0
# 160305               711.0            9.0                       2.0
# 160306              2120.0            9.0                       2.0
# 160307               179.0            6.0                       5.0
# 160308              1477.0            6.0                       2.0
# 160309              1588.0            8.0                       1.0
# 160310               995.0            8.0                       2.0
# 160311               614.0            2.0                       5.0
# 160312               178.0            5.0                       0.0
# 160313               402.0            6.0                       4.0
# 160314              1476.0            9.0                       1.0
# 160315              1773.0            8.0                       5.0
# 160316              1252.0            1.0                       2.0
# 160317              1477.0            6.0                       2.0
# 160318               246.0            2.0                       1.0
# 160319              2211.0            1.0                       2.0
# 160320              1283.0            2.0                       0.0
# 160321               713.0            9.0                       5.0
# 160322              1208.0            1.0                       0.0
# 160323               182.0            1.0                       0.0
# 160324              1476.0            6.0                       1.0
# 160325              1532.0            6.0                       0.0
# 160326              1480.0            6.0                       2.0
# 160327               573.0            1.0                       5.0
# 160328               715.0            6.0                       0.0
# 160329               832.0            5.0                       2.0
#
# [160330 rows x 25 columns]

# %%
# Make submission file

fashion_submit_dict = {}
fashion_submit_dict['id'] = []
fashion_submit_dict['tagging'] = []

beauty_submit_dict = {}
beauty_submit_dict['id'] = []
beauty_submit_dict['tagging'] = []

mobile_submit_dict = {}
mobile_submit_dict['id'] = []
mobile_submit_dict['tagging'] = []

for column in fashion_feature_columns:
    for index, row in df_fashion_val.iterrows():
        fashion_submit_dict['id'].append(str(row['itemid']) + "_" + column)
        fashion_submit_dict['tagging'].append(row[column])

for column in beauty_feature_columns:
    for index, row in df_beauty_val.iterrows():
        beauty_submit_dict['id'].append(str(row['itemid']) + "_" + column)
        beauty_submit_dict['tagging'].append(row[column])

for column in mobile_feature_columns:
    for index, row in df_mobile_val.iterrows():
        mobile_submit_dict['id'].append(str(row['itemid']) + "_" + column)
        mobile_submit_dict['tagging'].append(row[column])

# %%
df_fashion_submit = pd.DataFrame(fashion_submit_dict)
df_beauty_submit = pd.DataFrame(beauty_submit_dict)
df_mobile_submit = pd.DataFrame(mobile_submit_dict)

final_submit = df_fashion_submit.append([df_mobile_submit, df_beauty_submit])
final_submit.to_csv('submission_2103_1.csv', index = False)

# %%
final_submit.to_csv('./submission_2103.csv', index = False)

# %%
df_f
# Out:
#                              id tagging
# 0        381034175_Collar Type   3 8
# 1        396355150_Collar Type   1 8
# 2        592583745_Collar Type   1 4
# 3        721929368_Collar Type   0 3
# 4        800794259_Collar Type   3 1
# 5        959172548_Collar Type   0 6
# 6        962038495_Collar Type   3 1
# 7        1029774483_Collar Type  1 8
# 8        1067777027_Collar Type  1 3
# 9        1270302483_Collar Type  3 15
# 10       1284093055_Collar Type  8 0
# 11       1392497932_Collar Type  3 15
# 12       1451569176_Collar Type  13 10
# 13       1512677687_Collar Type  3 1
# 14       1569212797_Collar Type  3 15
# 15       1639443070_Collar Type  3 1
# 16       1660883608_Collar Type  8 1
# 17       1666499876_Collar Type  1 3
# 18       1690179744_Collar Type  1 3
# 19       1695487131_Collar Type  1 6
# 20       1703984083_Collar Type  8 3
# 21       1705600680_Collar Type  3 15
# 22       1787168327_Collar Type  1 3
# 23       1792870258_Collar Type  1 10
# 24       1805902832_Collar Type  8 1
# 25       1821404122_Collar Type  8 1
# 26       1823022881_Collar Type  1 3
# 27       1823033426_Collar Type  3 13
# 28       1832687846_Collar Type  8 1
# 29       1860881445_Collar Type  8 1
# ...                         ...  ...
# 1174772  1782786883_Skin_type    7 0
# 1174773  1783391715_Skin_type    4 2
# 1174774  1786798701_Skin_type    0 1
# 1174775  1787316578_Skin_type    0 6
# 1174776  1787632638_Skin_type    0 6
# 1174777  1788718999_Skin_type    0 2
# 1174778  1789804544_Skin_type    0 1
# 1174779  1793720209_Skin_type    0 2
# 1174780  1794583570_Skin_type    0 2
# 1174781  1795462556_Skin_type    0 4
# 1174782  1804494348_Skin_type    0 1
# 1174783  1806226561_Skin_type    0 4
# 1174784  1810849405_Skin_type    0 4
# 1174785  1811176817_Skin_type    0 2
# 1174786  1811673680_Skin_type    2 4
# 1174787  1811889388_Skin_type    0 1
# 1174788  1812100249_Skin_type    3 0
# 1174789  1813046604_Skin_type    6 2
# 1174790  1813629660_Skin_type    3 0
# 1174791  1815101480_Skin_type    0 2
# 1174792  1818918983_Skin_type    0 3
# 1174793  1819459292_Skin_type    0 3
# 1174794  1821997730_Skin_type    4 0
# 1174795  1823139406_Skin_type    0 6
# 1174796  1824884851_Skin_type    0 4
# 1174797  1826670507_Skin_type    0 1
# 1174798  1832111687_Skin_type    0 3
# 1174799  1832269907_Skin_type    0 4
# 1174800  1832929407_Skin_type    0 1
# 1174801  1833165562_Skin_type    0 1
#
# [1174802 rows x 2 columns]

# %%
df_na['tagging'] = np.nan

# %%
df_na.to_csv('testing.csv', index = False)

# %%
for cat in categories:
    for column in '{}_feature_columns'.format(cat):
        print (column)
# Out:
# b
# e
# a
# u
# t
# y
# _
# f
# e
# a
# t
# u
# r
# e
# _
# c
# o
# l
# u
# m
# n
# s
# f
# a
# s
# h
# i
# o
# n
# _
# f
# e
# a
# t
# u
# r
# e
# _
# c
# o
# l
# u
# m
# n
# s
# m
# o
# b
# i
# l
# e
# _
# f
# e
# a
# t
# u
# r
# e
# _
# c
# o
# l
# u
# m
# n
# s

# %%
import pandas as pd
